# %% [markdown]
# <a href="https://colab.research.google.com/github/thumb-chuu/BigData-Internship_WebCrawling/blob/main/%EC%97%84%EC%A7%80%EC%88%98_%EC%8B%A4%EC%8A%B5(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - python_crawler_3.ipynb실습

# %% [markdown]
# - URL 목록 추출을 위한 scrape_list_page() 함수 정의
# - scrape_list_page() 함수의 반환값은 list처럼 반복 가능한 제너레이터로 구현

# %%
import requests
import lxml.html
# !pip install cssselect
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cssselect in /usr/local/lib/python3.7/dist-packages (1.1.0)

# %%
def main():
    """
    크롤러의 메인 처리
    """
    # 여러 페이지에서 크롤링을 위해 Session 사용
    session = requests.Session()  
    # scrape_list_page() 함수를 호출해서 제너레이터를 추출
    response = session.get('http://www.hanbit.co.kr/store/books/new_book_list.html')
    urls = scrape_list_page(response)
    # 제너레이터는 list처럼 사용 가능
    for url in urls:
        print(url)
        print('-'*70)

# %%
def scrape_list_page(response):
    root = lxml.html.fromstring(response.content)
    root.make_links_absolute(response.url)
    for a in root.cssselect('.view_box .book_tit a'):
        url = a.get('href')
        # yield 구문으로 제너레이터의 요소 반환
        yield url

# %%
if __name__ == '__main__':
    main()
# Out:
# https://www.hanbit.co.kr/store/books/look.php?p_code=B3178834938
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B6084607806
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B8948111854
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B8661740335
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B1382037871
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B2847674054
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B4162156367
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B5156679966
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B6189263297
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B4813114979
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B8806843023
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B2859439220
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B1996635146
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B9063949643
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B7400451696
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B6129400746
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B7738896383
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B4354575770
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B1959656080
# ----------------------------------------------------------------------
# https://www.hanbit.co.kr/store/books/look.php?p_code=B5171715268
# ----------------------------------------------------------------------

# %% [markdown]
# - python_crawler_4.ipynb실습

# %%
import requests
import lxml.html
# !pip install cssselect
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cssselect in /usr/local/lib/python3.7/dist-packages (1.1.0)

# %%
def main():
    # 여러 페이지에서 크롤링을 위해 Session 사용
    session = requests.Session()  
    # scrape_list_page() 함수를 호출해서 제너레이터를 추출
    response = session.get('http://www.hanbit.co.kr/store/books/new_book_list.html')
    urls = scrape_list_page(response)
    for url in urls:
        response = session.get(url)  # Session을 사용해 상세 페이지를 추출
        ebook = scrape_detail_page(response)  # 상세 페이지에서 상세 정보를 추출
        print(ebook)  # 상세 정보 출력

# %%
def scrape_list_page(response):
    root = lxml.html.fromstring(response.content)
    root.make_links_absolute(response.url)
    for a in root.cssselect('.view_box .book_tit a'):
        url = a.get('href')
        yield url

# %%
def scrape_detail_page(response):
    """f
    상세 페이지의 Response에서 책 정보를 dict로 추출
    """
    root = lxml.html.fromstring(response.content)
    ebook = {
        'url': response.url,
        'title': root.cssselect('.store_product_info_box h3')[0].text_content(),
        'price': root.cssselect('.pbr strong')[0].text_content(),
        'content': [p.text_content()\
            for p in root.cssselect('#tabs_3 .hanbit_edit_view p')]
    }
    return ebook

# %%
if __name__ == '__main__':
    main()
# Out:
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B3178834938', 'title': '받침 없는 한글 동화 : 4권 세트', 'price': '49,680', 'content': ['', '\r\n\t\t<1편>\r\n', '이렇게 읽어요', '1. 무시무시 마녀가 이사 와!', '2. 아기 고래 뿌우의 노래', '\xa0', '\r\n\t\t<2편>\r\n', '이렇게 읽어요', '1. 도, 도, 도깨비다!', '2. 느티나무 아파트', '\xa0', '\r\n\t\t<3편>\r\n', '이렇게 읽어요', '1. 바쁘다 바빠 너구리 바빠', '2. 꼬마 지우개 마구마구', '\xa0', '\r\n\t\t<4편>\r\n', '이렇게 읽어요', '1. 도깨비 파자마 파티', '2. 꼬마 두루미 뚜루']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B6084607806', 'title': '받침 없는 한글 동화 : 도, 도, 도깨비다!', 'price': '12,420', 'content': ['', '이렇게 읽어요', '1. 도, 도, 도깨비다!', '2. 느티나무 아파트']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B8948111854', 'title': '받침 없는 한글 동화 : 도깨비 파자마 파티', 'price': '12,420', 'content': ['', '이렇게 읽어요', '1. 도깨비 파자마 파티', '2. 꼬마 두루미 뚜루']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B8661740335', 'title': '받침 없는 한글 동화 : 무시무시 마녀가 이사 와!', 'price': '12,420', 'content': ['', '이렇게 읽어요', '1. 무시무시 마녀가 이사 와!', '2. 아기 고래 뿌우의 노래']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B1382037871', 'title': '받침 없는 한글 동화 : 바쁘다 바빠 너구리 바빠', 'price': '12,420', 'content': ['', '이렇게 읽어요', '1. 바쁘다 바빠 너구리 바빠', '2. 꼬마 지우개 마구마구']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B2847674054', 'title': '리얼 몽골 [2022~2023 최신판]', 'price': '16,200', 'content': ['', '작가의 말', '몽골 지역 구분', '구글 지도 활용', '\r\n\t\t\t\r\n', '\xa0', '\r\n\t\t\tPART 01 한눈에 보는 몽골\xa0\r\n', '\xa0', '한눈에 보는 몽골\xa0', '숫자로 보는 몽골\xa0', '몽골 기본 정보\xa0', '몽골 문화와 에티켓\xa0', '몽골 연중 날씨\xa0', '몽골 4색 테마 여행\xa0', '몽골 여행 키워드 10\xa0', '몽골 필수 여행지 10\xa0', '몽골 문화 & 역사\xa0', '\r\n\t\t\t\r\n', '\r\n\t\t\t추천 여행 코스\xa0\r\n', '완전 정복 2주 코스\xa0', '고비 사막 1주 코스\xa0', '홉스골 10일 코스\xa0', '울란바토르 알짜배기 코스', '테렐지 1박 2일 코스', '\xa0', '\xa0', '\r\n\t\t\tPART 02 몽골을 가장 멋지게 여행하는 방법\xa0\r\n', '\r\n\t\t\t\r\n', '\r\n\t\t\t테마 여행\xa0\r\n', '액티비티\xa0', '몽골 동물\xa0', '전통 공연\xa0', '종교 문화\xa0', '불교 사원\xa0', '박물관 & 미술관\xa0', '나담 축제\xa0', '차강사르\xa0', '\xa0', '\r\n\t\t\t미식 여행\xa0\r\n', '전통 음식\xa0', '몽골리안 바비큐 & 핫팟\xa0', '럭셔리 레스토랑\xa0', '라운지 바 & 클럽\xa0', '몽골 맥주 & 보드카\xa0', '몽골 베이커리\xa0', '몽골 전통 음료\xa0', '\xa0', '\r\n\t\t\t쇼핑 여행\xa0\r\n', '여행 기념품점\xa0', '추천 기념품\xa0', '마트 & 드럭스토어 아이템\xa0', '캐시미어 아웃렛\xa0', '백화점 & 쇼핑몰\xa0', '전통시장 & 대형마트\xa0', '\xa0', '\xa0', '\r\n\t\t\tPART 03 쉽고 즐거운 여행 준비\r\n', '\xa0', '\r\n\t\t\t준비 편\xa0\r\n', '몽골 여행 계획하기\xa0', '여행 준비 캘린더\xa0', '투어 차량 선택 노하우\xa0', '여행사 선정 방법\xa0', '은하수 촬영 꿀팁\xa0', '몽골 여행 준비물\xa0', '웹사이트 & 애플리케이션\xa0', '\xa0', '\r\n\t\t\t실전 편\xa0\r\n', '몽골 입국 절차\xa0', '칭기즈칸 국제공항\xa0', '울란바토르 시티투어 버스\xa0', '몽골 종단 철도\xa0', '환전 및 유심 카드\xa0', '[REAL GUIDE] 몽골 화폐\xa0', '추천 장보기 리스트\xa0', '몽골 여행 생활 가이드\xa0', '몽골 숙소의 모든 것\xa0', '\xa0', '\xa0', '\r\n\t\t\tPART 04 진짜 몽골을 만나는 시간\xa0\r\n', '\xa0', '구역별로 만나는 몽골\xa0', '\xa0', '\r\n\t\t\t몽골 여행의 시작 울란바토르\xa0\r\n', '울란바토르 대중교통\xa0', '\xa0', '\r\n\t\t\tSECTION A 울란바토르 중심부\xa0\r\n', '상세 지도\xa0', '추천 스폿\xa0', '\xa0', '\r\n\t\t\tSECTION B 울란바토르 서남부\xa0\r\n', '상세 지도\xa0', '추천 스폿\xa0', '\xa0', '[REAL GUIDE]', '숨은 한국 찾기\xa0', '\xa0', '\r\n\t\t\tSECTION C 울란바토르 동부\xa0\r\n', '상세 지도\xa0', '추천 스폿\xa0', '\xa0', '\r\n\t\t\t초원 위 힐링 여행지 테렐지 국립공원\xa0\r\n', '상세 지도\xa0', '가는 방법\xa0', '추천 스폿\xa0', '\xa0', '[REAL GUIDE]', '13세기 마을 테마 공원\xa0', '전통가옥 게르\xa0', '\xa0', '\r\n\t\t\t몽골 여행의 하이라이트 고비 사막\xa0\r\n', '상세 지도\xa0', '추천 스폿\xa0', '\xa0', '[REAL GUIDE]', '낙타 체험 & 모래 썰매\xa0', '\xa0', '\r\n\t\t\t몽골의 푸른 보석 홉스골\xa0\r\n', '상세 지도\xa0', '추천 스폿\xa0', '\xa0', '[REAL GUIDE]', '쳉헤르의 5대 온천\xa0', '홉스골 호수\xa0', '승마·ATV·수중 액티비티 체험', '\xa0', 'INDEX']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B4162156367', 'title': '오늘도 시작하지 못하는 당신을 위해', 'price': '14,850', 'content': ['', '프롤로그', '\xa0', '\r\n\t\t\t1장 완벽주의자의 탄생\r\n', '당신은 완벽주의자인가요?', '\xa0: 저는 완벽주의자가 아니에요', '\xa0: 이론 속 완벽주의자 유형', '우리는 어쩌면 대부분 완벽주의자', '\xa0: 생활 속 완벽주의자 유형', '\xa0 -회피형 완벽주의자', '\xa0 -감독형 완벽주의자', '\xa0 -자책형 완벽주의자', '\xa0 -안정형 완벽주의자', '\xa0', '\r\n\t\t\t2장 완벽주의, 스스로 만든 정신적 감옥\r\n', '우리는 모두 완벽을 강요당한다', '\xa0: 성과주의 문화가 낳은 괴물', '\xa0: 1등이 되면 고민은 끝이라는 착각', '\xa0: 온라인 세상으로 맞이한 또 다른 완벽주의', '\xa0: 불안과 우울, 그 너머에 있는 마음', '완벽주의자가 빠지기 쉬운 네 가지 함정', '\xa0: 지금 당장 버려야 할 완벽주의 생각 습관', '\xa0 -당위성(should)의 오류', '\xa0 -흑백논리의 오류', '\xa0 -과잉(지나친) 일반화', '\xa0 -재앙화(파국화) 사고', '\xa0', '\r\n\t\t\t3장 완벽주의 성향이 높은 편입니다\r\n', '완벽주의가 삶에 지장을 주려 할 때', '\xa0: 완벽주의 성향을 파악하는 척도', '\xa0: 완벽주의자의 성격', '\xa0: 나는 이만하면 괜찮은 완벽주의자?', '완벽주의 늪에 빠진 사람들', '\xa0: 양육 환경으로 완벽주의가 대물림된다', '\xa0: 평가에 민감한 사람들', '\xa0: 타인의 인정이 삶의 목표가 될 수는 없다', '완벽하려는 강박이 불러오는 이상 증세', '\xa0: 완벽주의자가 감정을 대하는 방식', '\xa0: 완벽주의자를 누르고 있는 감정들', '\xa0 -죄책감과 수치심', '\xa0 -걱정과 불안', '\xa0 -우울과 슬픔', '\xa0: 완벽주의자가 낳은 질병들', '\xa0 -강박장애', '\xa0 -섭식장애', '\xa0 -번아웃', '\xa0 -무대 공포증', '\xa0', '\r\n\t\t\t4장 완벽주의의 균형을 찾아서\r\n', '완벽주의라는 허상', '\xa0: 낮은 완벽주의, 높은 성취감', '\xa0: 완벽주의자에게 진짜 필요한 능력', '서로가 서로를 도울 수 있다', '\xa0: 완벽주의자가 쉽게 우울해지는 이유', '\xa0: 완벽주의자를 둘러싼 관계 재조명', '\xa0 -부모와 자녀', '\xa0 -부부 혹은 연인', '\xa0 -리더와 조직원', '\xa0', '\r\n\t\t\t5장 완벽주의 성향이 높은 편입니다\r\n', '1주차_인정하라', '\xa0: 성과를 가로막는 진짜 장애물을 파악하라', '\xa0: 인정하는 연습, 나는 완벽주의자입니다', '2주차_기준을 바꾸라', '\xa0: 완벽주의자들의 비현실적인 기준', '\xa0: 기준을 바꾸는 연습', '3주차_두려움의 뿌리를 찾아라', '\xa0: 부정적인 감정 들여다보기', '\xa0: 혼자서 자동적 사고를 찾아보고 싶을 때', '4주차_실수에 대한 두려움을 버리고 계속 시도하기', '\xa0: 실수를 두려워하지 않는 사람은 없다', '\xa0: 실수를 기회로 바꾸는 방법', '5주차_완벽하지 않아서 행복한 사람들', '\xa0: 완벽주의를 조절하는 현실적인 기법', '\xa0: 내 안의 안정형 완벽주의를 키우자', '\xa0', '\r\n\t\t\t6장 완벽을 포기하고 완벽에 가까워진 사람들\r\n', '행복한 똑똑이가 되는 진짜 비결', '\xa0: 진짜 필요한 능력, 자기 효능감', '\xa0: 타인이 아닌 자신을 위한 노력', '두 마리 토끼를 모두 잡으려면', '\xa0: 역할 과부하에 시달리는 엄마들', '\xa0: 버거운 말을 거절하는 연습', '유니콘 기업의 건강한 조직 문화', '\xa0: 조직이 개인 퍼포먼스를 돕는 이유', '\xa0: 완벽하지 않은 조직문화의 가치', '운동선수도 피할 수 없는 완벽주의', '\xa0: 운동의 흐름을 방해하는 큰 위기, 입스', '\xa0: 심리적 불안이 일으킨 신체적 증상', '\xa0: 맹목적인 경쟁심에 사로잡히지 않으려면', '\xa0', '에필로그', '주', '부록: 완벽주의 극복 5주 프로그램 워크북']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B5156679966', 'title': 'IT CookBook, 원리로 이해하는 전력전자공학(2판)', 'price': '30,000', 'content': ['', '\r\n\t\t\t\t\t\t\tCHAPTER 01 전력전자공학의 기초\r\n', '1.1 개요', '1.2 기초 회로이론', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\tCHAPTER 02 전력용 반도체 스위치\r\n', '2.1 개요', '2.2 다이오드', '2.3 전력용 트랜지스터', '2.4 사이리스터\xa0', '2.5 MOSFET\xa0', '2.6 IGBT', '2.7 와이드 밴드 갭 소자', '2.8 전력용 반도체 스위치 비교', '2.9 추가 부품', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\tCHAPTER 03 정류기와 AC-AC 컨버터\r\n', '3.1 개요', '3.2 단상 반파 정류기', '3.3 단상 전파 정류기', '3.4 3상 반파 정류기', '3.5 3상 전파 정류기', '3.6 AC-AC 컨버터', '3.7 전원 측 인덕턴스의 영향', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\tCHAPTER 04 비절연형 DC-DC 컨버터\r\n', '4.1 개요', '4.2 강압형 컨버터', '4.3 승압형 컨버터', '4.4 승강압형 컨버터', '4.5 비절연형 DC-DC 컨버터의 설계', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\tCHAPTER 05 절연형 DC-DC 컨버터\r\n', '5.1 개요', '5.2 플라이백 컨버터 5.2', '5.3 포워드 컨버터 5.3', '5.4 푸시풀 컨버터', '5.5 하프 브리지 컨버터', '5.6 풀 브리지 컨버터', '5.7 역률 개선 회로', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\tCHAPTER 06 인버터\r\n', '6.1 개요', '6.2 단상 하프 브리지 인버터', '6.3 단상 풀 브리지 인버터', '6.4 3상 전압원 인버터', '6.5 3상 전류원 인버터', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\tCHAPTER 07 공진형 컨버터\r\n', '7.1 개요', '7.2 준 공진형 컨버터', '7.3 부하 공진형 컨버터', '7.4 위상천이 풀 브리지 컨버터', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\tCHAPTER 08 고전압 대용량 전력변환\r\n', '8.1 개요', '8.2 다이오드 클램프 멀티레벨 인버터', '8.3 캐스케이디드 H-브리지 인버터', '8.4 모듈러 멀티레벨 컨버터', '8.5 다중 펄스 다이오드 정류기', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\tCHAPTER 09 신재생에너지\r\n', '9.1 개요', '9.2 풍력에너지 시스템', '9.3 태양광에너지 시스템', '9.4 연료전지 시스템', '9.5 에너지 저장 시스템', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\tCHAPTER 10 전력전자 응용\r\n', '10.1 개요', '10.2 유연 송전시스템(FACTS)', '10.3 마이크로그리드와 직류 송배전 기술', '10.4 반도체 변압기', '10.5 전기추진 응용', '10.6 핵융합 발전', '10.7 가전 응용', '연습문제']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B6189263297', 'title': '트러스트', 'price': '16,920', 'content': ['', '감사의 말 | 이 책에서 다룰 내용\xa0', '\xa0', '\r\n\t\t\t\tChapter 1. 신뢰의 역사\xa0\r\n', '생물학 | 선물 | 종교 | 중세의 시장과 국제무역 | 법률\xa0', '\xa0', '\r\n\t\t\t\tChapter 2. 전문기관에 대한 신뢰\xa0\r\n', '정치인 | 미디어 | 의학에 대한 신뢰 | 과학 | 기후변화\xa0', '\xa0', '\r\n\t\t\t\tChapter 3. 서로 신뢰하기\xa0\r\n', '낯선 사람에 대한 신뢰 | 자신에 대한 신뢰 | 사과와 비난 | 정체성, 존엄성, 프라이버시\xa0', '\xa0', '\r\n\t\t\t\tChapter 4. 신뢰의 경제학\xa0\r\n', '신뢰에 대한 경제학 서적을 읽는 이유 | 내가 신뢰에 대한 경제학 책을 쓴 이유 | 신뢰에 대한 경제학자의 생각 | 경제학적 신뢰이론 | 인과관계와 실증경제학자의 방법론\xa0', '\xa0', '\r\n\t\t\t\tChapter 5. 현대경제와 신뢰\r\n', '화폐 | 투자와 금융 | 계약 | 직장 | 브랜드 | 시장경제와 신뢰의 미래: 공유 경제와 블록체인\xa0', '\xa0', '\r\n\t\t\t\tChapter 6. 결론\r\n', '\xa0', '주 | 찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B4813114979', 'title': '구글 앱스 스크립트 완벽 가이드', 'price': '36,000', 'content': ['', '\r\n\t\t\t\t\t\tChapter 1 구글 앱스 스크립트 기본 지식\r\n', '1.1 구글 앱스 스크립트', '1.2 구글 앱스와 구글 워크스페이스', '1.3 GAS로 조작할 수 있는 애플리케이션', '1.4 GAS 학습 시 주의할 점', '\xa0', '\r\n\t\t\t\t\t\tChapter 2 스크립트 편집기와 대시보드\r\n', '2.1 헬로! GAS', '2.2 프로젝트와 스크립트', '2.3 스크립트 편집기의 편집 기능', '2.4 로그와 디버그', '2.5 권한과 허가', '2.6 지원 메뉴와 레퍼런스', '\xa0', '\r\n\t\t\t\t\t\tChapter 3 기본 문법\r\n', '3.1 자바스크립트 기초', '3.2 변수와 상수', '3.3 데이터 타입', '3.4 배열', '3.5 객체', '3.6 산술 연산자와 대입 연산자', '\r\n\t\t\t\t\t\t\r\n', '\r\n\t\t\t\t\t\tChapter 4 제어문\r\n', '4.1 if문을 이용한 조건 분기', '4.2 조건식, 비교 연산자, 논리 연산자', '4.3 switch문을 이용한 다중 분기', '4.4 while문을 이용한 반복', '4.5 for문을 이용한 반복', '4.6 for...of문을 이용한 반복', '4.7 for...in문을 이용한 반복', '4.8 반복 처리 중단과 건너뛰기', '4.9 try...catch문과 예외 처리', '\xa0', '\r\n\t\t\t\t\t\tChapter 5 함수\r\n', '5.1 함수', '5.2 함수 리터럴', '5.3 스코프', '\xa0', '\r\n\t\t\t\t\t\tChapter 6 클래스와 객체\r\n', '6.1 객체, 속성, 메서드', '6.2 클래스와 인스턴스화', '6.3 메서드와 프로토타입', '6.4 정적 멤버', '\xa0', '\r\n\t\t\t\t\t\tChapter 7 자바스크립트의 내장 객체\r\n', '7.1 내장 객체', '7.2 수치 다루기 - Number 객체', '7.3 문자열 다루기 - String 객체', '7.4 배열 다루기 - Array 객체', '7.5 함수 다루기 - Function 객체', '7.6 날짜와 시간 다루기 - Date 객체', '7.7 정규 표현 다루기 - RegExp 객체', '7.8 예외 정보 얻기 - Error 객체', '7.9 수학 연산 실행하기 - Math 객체', '7.10 JSON 데이터 다루기 - JSON 객체', '7.11 객체 다루기 - Object 객체', '7.12 글로벌 함수', '\xa0', '\r\n\t\t\t\t\t\tChapter 8 스프레드시트\r\n', '8.1 Spreadsheet 서비스', '8.2 SpreadsheetApp 클래스', '8.3 스프레드시트 조작하기 - Spreadsheet 클래스', '8.4 시트 조작하기 - Sheet 클래스', '8.5 셀 범위 조작하기 - Range 클래스', '8.6 배열을 사용한 데이터 처리', '8.7 커스텀 함수', '\xa0', '\r\n\t\t\t\t\t\tChapter 9 지메일\r\n', '9.1 Gmail 서비스', '9.2 GmailApp 클래스', '9.3 스레드 얻기', '9.4 스레드 다루기 - GmailThread 클래스', '9.5 메시지 얻기', '9.6 메시지 다루기 - GmailMessage 클래스', '\xa0', '\r\n\t\t\t\t\t\tChapter 10 드라이브\r\n', '10.1 Drive 서비스', '10.2 DriveApp 클래스', '10.3 폴더 조작하기 - Folder 클래스', '10.4 파일 조작하기 - File 클래스', '10.5 폴더와 파일 컬렉션 조작하기', '10.6 폴더와 파일 공유 및 권한 조작하기', '\xa0', '\r\n\t\t\t\t\t\tChapter 11 캘린더\r\n', '11.1 Calendar 서비스', '11.2 CalendarApp 클래스', '11.3 캘린더 조작하기 - Calendar 클래스', '11.4 이벤트 조작하기 - CalendarEvent 클래스', '\xa0', '\r\n\t\t\t\t\t\tChapter 12 문서\r\n', '12.1 Document 서비스', '12.2 DocumentApp 클래스', '12.3 문서 조작하기 - Document 클래스', '12.4 섹션 조작하기', '12.5 단락 및 리스트 아이템 조작하기', '12.6 텍스트 객체 조작하기', '12.7 문자열 수정과 서식 설정', '12.8 문자열 찾기와 바꾸기', '\xa0', '\r\n\t\t\t\t\t\tChapter 13 프레젠테이션\r\n', '13.1 Slides 서비스', '13.2 SlidesApp 클래스', '13.3 프레젠테이션 조작하기 - Presentation 클래스', '13.4 프레젠테이션 조작하기 - Slide 클래스', '13.5 페이지 요소 조작하기', '13.6 텍스트 범위와 문자열 조작하기', '\xa0', '\r\n\t\t\t\t\t\tChapter 14 설문지\r\n', '14.1 Forms 서비스', '14.2 FormApp 클래스', '14.3 설문지 조작하기 - Form 클래스', '14.4 아이템 조작하기', '\xa0', '\r\n\t\t\t\t\t\tChapter 15 번역\r\n', '15.1 Language 서비스와 LanguageApp 클래스', '\xa0', '\r\n\t\t\t\t\t\tChapter 16 Base 서비스\r\n', '16.1 Base 서비스', '16.2 로그', '16.3 세션과 사용자', '\r\n\t\t\t\t\t\t\r\n', '\r\n\t\t\t\t\t\tChapter 17 사용자 인터페이스\r\n', '17.1 UI 조작과 UI 클래스', '17.2 다이얼로그', '17.3 메뉴', '17.4 스프레드시트 UI 확장하기', '\xa0', '\r\n\t\t\t\t\t\tChapter 18 파일과 데이터 조작\r\n', '18.1 Blob 객체', '18.2 첨부 파일 조작하기', '\xa0', '\r\n\t\t\t\t\t\tChapter 19 Utilities 서비스\xa0\r\n', '19.1 Utilities 서비스', '19.2 ZIP 파일과 CSV 파일', '19.3 날짜와 시간을 문자열로 바꾸기', '\xa0', '\r\n\t\t\t\t\t\tChapter 20 Properties 서비스\r\n', '20.1 속성 저장소', '20.2 Properties 서비스와 PropertiesService 클래스', '20.3 속성 저장소 읽고 쓰기 - Properties 클래스', '\xa0', '\r\n\t\t\t\t\t\tChapter 21 이벤트와 트리거\r\n', '21.1 심플 트리거', '21.2 인스톨러블 트리거', '21.3 이벤트 객체', '21.4 Script 서비스', '\xa0', '\r\n\t\t\t\t\t\tChapter 22 외부 서비스 접속\r\n', '22.1 Url Fetch 서비스', '22.2 HTTP 리퀘스트와 HTTP 리스폰스', '22.3 HTML, JSON에서 데이터 추출하기', '\xa0', '\r\n\t\t\t\t\t\tChapter 23 라이브러리\r\n', '23.1 라이브러리 이용하기', '23.2 라이브러리 만들기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B8806843023', 'title': '리얼 싱가포르 [2022~2023 최신판]', 'price': '16,200', 'content': ['', '작가의 말', '이 책의 사용법', '\xa0', '\r\n\t\t\t\tPART 01 미리 보는 싱가포르\r\n', '한눈에 보는 싱가포르', '숫자로 보는 싱가포르', '싱가포르 여행 기본 정보', '싱가포르 명절 & 축제', '싱가포르 여행의 매력', '싱가포르 여행 버킷 리스트', '이건 꼭 먹자! 싱가포르 음식', '이건 꼭 사자! 싱가포르 아이템', '키워드로 읽는 싱가포르 역사', '알아두면 유용한 싱가포르 문화', '\xa0', '\r\n\t\t\t\t[REAL GUIDE]\r\n', '싱가포르 대중교통 이용하기', '파인다이닝 즐기기', '한정판 야경의 매력, 아이라이트 싱가포르', '센토사를 오가는 교통수단', '유니버설 스튜디오 싱가포르 예습하기', '싱가포르 4대 동물원 총정리', '여행의 마지막을 알뜰하게! GST 환급 받기', '공항 속 복합 쇼핑몰 주얼 창이 싱가포르', '\xa0', '\xa0', '\r\n\t\t\t\tPART 02 싱가포르를 가장 멋지게 여행하는 방법\r\n', '\r\n\t\t\t\t\r\n', '\r\n\t\t\t\tTHEME\r\n', '레이저 쇼', '사원', '박물관', '전통 건축물', '현대 건축물', '시티 정글', '도서관 & 서점', '센토사의 명물', '루프톱 바', '\xa0', '\r\n\t\t\t\tFOOD\r\n', '스타 셰프 레스토랑', '파인다이닝', '브런치 카페', '애프터눈 티', '호커 센터 & 푸드코트', '콘셉트 레스토랑', '로컬 맛집', '인스타그래머블 카페', '커피 맛집', '중국 음식', '싱가포르 베스트 바', '\xa0', '\r\n\t\t\t\tSHOPPING\r\n', '오차드 로드 대표 쇼핑몰', '기념품 쇼핑', '개성 만점 편집숍', '로컬 디자이너 브랜드', '현지 마트', '\xa0', '\r\n\t\t\t\tREAL COURSE GUIDE\r\n', '단기 집중 2박 3일 코스', '정석대로 핵심만 쏙쏙 3박 4일 코스', '느긋하게 즐기는 4박 5일 코스', '3박 4일 친구끼리 여행', '4박 5일 아이와 함께하는 가족 여행', '3박 4일 로맨틱 커플 여행', '3박 4일 식도락 여행', '\xa0', '\xa0', '\r\n\t\t\t\tPART 03 진짜 싱가포르를 만나는 시간\r\n', '\r\n\t\t\t\t\r\n', '\r\n\t\t\t\tAREA 1 올드 시티\r\n', '상세 지도', '추천 스폿', '\r\n\t\t\t\tAREA 2 마리나 베이\r\n', '상세 지도', '추천 스폿', '\r\n\t\t\t\tAREA 3 리버사이드\r\n', '상세 지도', '추천 스폿', '\r\n\t\t\t\tAREA 4 오차드 로드\r\n', '상세 지도', '추천 스폿', '\r\n\t\t\t\tAREA 5 차이나타운 & CBD\r\n', '상세 지도', '추천 스폿', '\r\n\t\t\t\tAREA 6 부기스\r\n', '상세 지도', '추천 스폿', '\r\n\t\t\t\tAREA 7 리틀 인디아\r\n', '상세 지도', '추천 스폿', '\r\n\t\t\t\tAREA 8 센토사 & 하버프런트\r\n', '상세 지도', '추천 스폿', '\xa0', '\xa0', '\r\n\t\t\t\tPART 04 개성 강한 주변 지역 여행\r\n', '\xa0', '\r\n\t\t\t\tPLUS AREA 1 뎀시 힐\r\n', '지도와 추천 코스', '추천 스폿', '\r\n\t\t\t\tPLUS AREA 2티옹바루\r\n', '지도와 추천 코스', '추천 스폿', '\r\n\t\t\t\tPLUS AREA 3 카통\r\n', '지도와 추천 코스', '추천 스폿', '\r\n\t\t\t\tPLUS AREA 4 홀랜드 빌리지\r\n', '지도와 추천 코스', '추천 스폿', '\xa0', '\xa0', '\r\n\t\t\t\tPART 05 쉽고 즐거운 여행 준비\r\n', '\xa0', 'GUIDE 01 여행 준비 & 출입국', 'GUIDE 02 숙소']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B2859439220', 'title': '원소 이야기', 'price': '15,300', 'content': ['', '머리말: 현실을 요리하는 법', '\xa0', '1장 원소 사냥에 뛰어든 천재들', '2장 쪼개지지 않는 근원', '3장 원자 모형의 진화', '4장 원자는 어디에서 올까?', '5장 주기율표의 서막이 열리다', '6장 양자역학으로 해결된 주기율표', '7장 불안하면 터진다', '8장 연금술사의 꿈이 이루어지다', '9장 금속원소와 전기', '10장 산, 비금속원소, 빛', '11장 생명을 구성하는 모든 것이 주기율표에 있다', '12장 세상을 바꾼 원소들', '\xa0', '부록', '감사의 말', '주']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B1996635146', 'title': '핸즈온 데이터 시각화', 'price': '34,200', 'content': ['', '\r\n\t\t\t\t\t\tCHAPTER 0 서문\r\n', '0.1 왜 데이터 시각화인가', '0.2 무엇을 믿을 수 있을까요', '0.3 더 설득력 있는 그림', '0.4 진실의 여러 가지 그림자', '0.5 책의 구성', '0.6 마치며', '\xa0', '\xa0', '\r\n\t\t\t\t\t\t[PART I 기본 기술]\r\n', '\r\n\t\t\t\t\t\t\r\n', '\r\n\t\t\t\t\t\tCHAPTER 1 스토리를 위한 도구 선택하기\xa0\r\n', '1.1 데이터 스토리 스케치하기', '1.2 도구를 선택할 때 고려해야 할 10가지 요소', '1.3 추천 도구', '1.4 패스워드 관리자 사용', '1.5 마치며', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 2 스프레드시트 스킬 강화하기\r\n', '2.1 스프레드시트 도구 선택', '2.2 CSV 또는 ODS 형식으로 다운로드하기', '2.3 구글 시트 복사본 만들기', '2.4 구글 시트 공유하기', '2.5 구글 시트 업로드하고 변환하기', '2.6 구글 시트에서 주소 지오코딩하기', '2.7 구글 설문지로 데이터 수집하기', '2.8 데이터 정렬 및 필터', '2.9 수식을 사용해 계산하기', '2.10 피벗 테이블을 사용해 데이터 요약하기', '2.11 VLOOKUP을 사용해 열 매칭하기', '2.12 스프레드시트와 관계형 데이터베이스', '2.13 마치며', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 3 데이터를 찾고 질문하기\r\n', '3.1 검색을 위한 질문 가이드', '3.2 공공 데이터와 개인 데이터', '3.3 민감한 데이터를 가리거나 집계하기', '3.4 오픈 데이터 저장소', '3.5 데이터 출처 남기기', '3.6 불량 데이터 인식하기', '3.7 데이터에 대해 질문하기', '3.8 마치며', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 4 지저분한 데이터 정리하기\r\n', '4.1 구글 시트 스마트 클린업', '4.2 찾기 및 바꾸기', '4.3 행과 열 바꾸기', '4.4 데이터를 서로 다른 열로 나누기', '4.5 데이터를 한 열에 합치기', '4.6 타불라를 사용해 PDF에서 테이블 추출하기', '4.7 오픈리파인으로 데이터 정리하기', '4.8 마치며', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 5 의미 있는 비교하기\r\n', '5.1 비교를 정확히 기술하기', '5.2 데이터 정규화하기', '5.3 편향된 비교 주의하기', '5.4 마치며', '\xa0', '\xa0', '\r\n\t\t\t\t\t\t[PART II 시각화 구축]\r\n', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 6 차트 만들기\r\n', '6.1 차트 디자인 원칙', '6.2 구글 시트 차트', '6.3 막대 차트와 열 차트', '6.4 히스토그램', '6.5 원형 차트, 선 차트, 영역 차트', '6.6 데이터래퍼 차트', '6.7 주석이 달린 차트', '6.8 범위 차트', '6.9 분산형 차트와 버블 차트', '\r\n\t\t\t\t\t\t6.10 태블로 퍼블릭 차트\t\r\n', '6.11 태블로 퍼블릭으로 만드는 분산형 차트', '6.12 필터링된 선 차트', '6.13 마치며', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 7 데이터를 지도로 시각화하기\r\n', '7.1 지도 디자인 원칙', '7.2 코로플레스 색상과 간격 디자인', '7.3 코로플레스 지도 데이터 정규화하기', '7.4 구글 내 지도로 만드는 포인트 지도', '7.5 데이터래퍼로 만드는 심벌 포인트 지도', '7.6 데이터래퍼로 만드는 코로플레스 지도', '7.7 태블로 퍼블릭으로 만드는 코로플레스 지도', '7.8 소크라타 오픈 데이터로 만드는 실시간 지도', '7.9 마치며', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 8 테이블을 활용한 시각화\r\n', '8.1 테이블 디자인 원칙', '8.2 스파크라인으로 만드는 데이터래퍼 테이블', '8.3 기타 테이블 생성 도구', '8.4 마치며', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 9 웹에 임베딩하기\r\n', '\r\n\t\t\t\t\t\t9.1 정적 이미지와 대화형 iframe\t\r\n', '9.2 임베드 코드 또는 iframe 태그 가져오기', '9.3 코드 또는 iframe을 웹사이트에 붙여넣기', '9.4 마치며', '\xa0', '\xa0', '\r\n\t\t\t\t\t\t[PART III 코드 템플릿과 고급 도구]\r\n', '\r\n\t\t\t\t\t\t\r\n', '\r\n\t\t\t\t\t\tCHAPTER 10 깃허브로 코드 수정하고 호스트하기\r\n', '10.1 간단한 리플릿 맵 템플릿 복사, 수정, 호스팅하기', '10.2 깃허브 페이지 링크를 iframe으로 변환하기', '10.3 깃허브에 새로운 레포 만들고 파일 업로드하기', '10.4 깃허브 데스크톱과 아톰 텍스트 편집기를 사용해 효율적인 코딩하기', '10.5 마치며', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 11 Chart.js와 하이차트 템플릿\r\n', '\r\n\t\t\t\t\t\t11.1 Chart.js로 만드는 막대 또는 열 차트\t\r\n', '11.2 Chart.js로 만드는 오류 바', '11.3 Chart.js로 만드는 선 차트', '11.4 하이차트로 만드는 주석이 달린 선 차트', '11.5 Chart.js로 만드는 분산형 차트', '11.6 Chart.js로 만드는 버블 차트', '11.7 마치며', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 12 리플릿 맵 템플릿\r\n', '12.1 구글 시트로 만드는 리플릿 맵', '12.2 구글 시트로 만드는 리플릿 스토리맵', '12.3 구글 시트 API 키 가져오기', '12.4 CSV 데이터로 만드는 리플릿 맵', '12.5 CSV 데이터로 만드는 리플릿 히트맵 포인트', '12.6 검색 가능한 리플릿 포인트 지도', '12.7 오픈 데이터 API로 만드는 리플릿 맵', '12.8 마치며', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 13 지도 데이터 변환하기\r\n', '13.1 지리 공간 데이터와 GeoJSON', '13.2 GeoJSON 경계 파일 찾기', '13.3 GeoJson.io를 사용해 그리고 편집하기', '13.4 맵셰이퍼를 사용해 편집하고 병합하기', '13.5 압축된 KMZ를 KML로 변환하기', '13.6 맵 워퍼로 지오레퍼런스하기', '13.7 미국 통계청 지오코더를 사용해 대량으로 지오코딩하기', '13.8 포인트 데이터를 폴리곤 데이터로 피벗하기', '13.9 마치며', '\xa0', '\xa0', '\r\n\t\t\t\t\t\t[PART IV 진실하고 의미 있는 스토리 전달하기]\r\n', '\r\n\t\t\t\t\t\t\r\n', '\r\n\t\t\t\t\t\tCHAPTER 14 거짓을 발견하고 편향 줄이기\r\n', '14.1 차트로 거짓말하는 방법', '14.2 지도로 거짓말하는 방법', '14.3 데이터 편향 인지하고 줄이기', '14.4 공간 편향 인지하고 줄이기', '14.5 마치며', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 15 데이터 스토리 말하고 보여주기\r\n', '15.1 스토리보드에 내러티브 작성하기', '15.2 의미에 주의를 기울이세요', '15.3 출처와 불확실성 인정하기', '15.4 데이터 스토리 형식 결정하기', '15.5 마치며', '\xa0', '\r\n\t\t\t\t\t\tAPPENDIX 자주 발생하는 문제 해결법\r\n', 'A.1 도구 또는 플랫폼 문제\xa0', 'A.2 다른 브라우저 사용해보기\xa0', 'A.3 개발 도구로 진단하기\ ...
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B9063949643', 'title': 'IT CookBook, TCP/IP 소켓 프로그래밍(2판)', 'price': '32,000', 'content': ['', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tChapter 01 네트워크와 소켓 프로그래밍\r\n', '01 TCP/IP 프로토콜 개요', '02 소켓의 개념', '03 소켓의 특징과 구조', '04 소켓 프로그램 맛보기', '실습 1-1 윈도우 소켓 프로그램 작성과 테스트', '실습 1-2 리눅스 소켓 프로그램 작성과 테스트', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tChapter 02 소켓 시작하기\r\n', '01 오류 처리', '02 소켓 초기화와 종료', '03 소켓 생성과 닫기', '실습 2-1 윈속 초기화와 종료하기', '실습 2-2 소켓 생성과 닫기', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tChapter 03 소켓 주소 구조체 다루기\r\n', '01 소켓 주소 구조체', '02 바이트 정렬 함수', '03 IP 주소 변환 함수', '04 DNS와 이름 변환 함수', '실습 3-1 바이트 정렬 함수 연습', '실습 3-2 IP 주소 변환 함수 연습', '실습 3-3 이름 변환 함수 연습', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tChapter 04 TCP 서버-클라이언트\r\n', '01 TCP 서버-클라이언트 구조', '02 TCP 서버-클라이언트 분석', '03 TCP 서버-클라이언트(IPv6)', '실습 4-1 TCP 서버-클라이언트 작성', '실습 4-2 TCP 서버-클라이언트 테스트', '실습 4-3 TCP 서버-클라이언트(IPv6) 작성과 테스트', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tChapter 05 데이터 전송하기\r\n', '01 응용 프로그램 프로토콜과 데이터 전송', '02 다양한 데이터 전송 방식', '실습 5-1 고정 길이 데이터 전송 연습', '실습 5-2 가변 길이 데이터 전송 연습', '실습 5-3 고정 길이 + 가변 길이 데이터 전송 연습', '실습 5-4 데이터 전송 후 종료 연습', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tChapter 06 멀티스레드: 윈도우\r\n', '01 스레드 기초', '02 스레드 API', '03 멀티스레드 TCP 서버', '04 스레드 동기화', '실습 6-1 스레드 생성과 종료, 인수 전달 연습', '실습 6-2 스레드 우선순위 변경 연습', '실습 6-3 스레드 실행 제어와 종료 기다리기 연습', '실습 6-4 멀티스레드 TCP 서버 작성과 테스트', '\xa0', '실습 6-5 임계 영역 연습', '실습 6-6 이벤트 연습', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tChapter 07 멀티스레드: 리눅스\r\n', '01 스레드 API', '02 멀티스레드 TCP 서버', '03 스레드 동기화', '실습 7-1 스레드 생성과 종료, 인수 전달 연습', '실습 7-2 스레드 우선순위 변경 연습', '실습 7-3 스레드 종료 기다리기 연습', '실습 7-4 멀티스레드 TCP 서버 작성과 테스트', '실습 7-5 뮤텍스 연습', '실습 7-6 조건 변수 연습', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tChapter 08 UDP 서버-클라이언트\r\n', '01 UDP 서버-클라이언트 구조', '02 UDP 서버-클라이언트 분석', '03 UDP 서버-클라이언트(IPv6)', '04 브로드캐스팅', '실습 8-1 UDP 서버-클라이언트 작성과 테스트', '실습 8-2 UDP 서버-클라이언트(IPv6) 작성과 테스트', '실습 8-3 UDP 브로드캐스팅 예제 작성과 테스트', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tChapter 09 소켓 옵션\r\n', '01 소켓 옵션의 종류와 관련 함수', '02 SOL_SOCKET 레벨 옵션', '03 IPPROTO_IP, IPPROTO_IPV6 레벨 옵션', '04 IPPROTO_TCP 레벨 옵션', '실습 9-1 SO_REUSEADDR 옵션 테스트', '실습 9-2 멀티캐스팅(IPv4) 예제 작성과 테스트', '실습 9-3 멀티캐스팅(IPv6) 예제 작성과 테스트', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tChapter 10 GUI 소켓 응용 프로그램: 윈도우\r\n', '01 GUI 응용 프로그램', '02 GUI 소켓 응용 프로그램', '03 대화상자 기반 응용 프로그램', '04 대화상자 기반 소켓 응용 프로그램', '실습 10-1 GUI 응용 프로그램 작성과 테스트', '실습 10-2 GUI 소켓 응용 프로그램 작성과 테스트', '실습 10-3 대화상자 기반 응용 프로그램 작성과 테스트', '실습 10-4 대화상자 기반 소켓 응용 프로그램 작성과 테스트', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tChapter 11 소켓 입출력 모델: 윈도우\r\n', '01 소켓 입출력 모델 개요', '02 Select 모델', '03 WSAAsyncSelect 모델', '04 Completion Port 모델', '05 소켓 입출력 모델 비교', '실습 11-1 넌블로킹 소켓 연습', '실습 11-2 Select 모델 TCP 서버 작성과 테스트', '실습 11-3 WSAAsyncSelect 모델 TCP 서버 작성과 테스트', '실습 11-4 Completion Port 모델 TCP 서버 작성과 테스트', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tChapter 12 소켓 입출력 모델: 리눅스\r\n', '01 소켓 입출력 모델 개요', '02 Select 모델', '03 Poll 모델', '04 EPoll 모델', '05 소켓 입출력 모델 비교', '실습 12-1 넌블로킹 소켓 연습', '실습 12-2 Select 모델 TCP 서버 작성과 테스트', '실습 12-3 Poll 모델 TCP 서버 작성과 테스트', '실습 12-4 EPoll 모델 TCP 서버 작성과 테스트', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tChapter 13 직렬 통신과 블루투스 통신: 윈도우\r\n', '01 직렬 통신', '실습 13-1 직렬 통신 프로그램 작성과 테스트', '02 블루투스 통신', '실습 13-2 블루투스 장치 검색 프로그램 작성과 테스트', '실습 13-3 블루투스 통신 프로그램 작성과 테스트', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tChapter 14 IPv4/IPv6 + TCP/UDP 지원 데이터 전송 프로그램\r\n', '01 프로젝트 개요', '02 응용 프로그램 작성', '실습 14-1 IPv4/IPv6 + TCP/UDP 지원 서버 작성', '실습 14-2 IPv4/IPv6 + TCP/UDP 지원 클라이언트 작성', '03 서버 코드 분석: 윈도우', '04 서버 코드 변환: 리눅스', '05 클라이언트 코드 분석', '06 추가 구현 사항']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B7400451696', 'title': 'IT CookBook, 쉽게 배우는 데이터 통신과 컴퓨터 네트워크(3판)', 'price': '30,000', 'content': ['', '\r\n\t\t\t\t\t\t\t\t\tChapter 01 네트워크 기초\r\n', '01 용어의 정의', '02 구조적 모델', '03 주소의 표현', '요약', '연습문제', '현장의 목소리 01', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 02 네트워크 개념\r\n', '01 프로토콜의 이해', '02 OSI 7계층 모델', '03 인터넷 모델', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 03 네트워크 기술\r\n', '01 라우팅 기능', '02 네트워크의 분류', '03 인터네트워킹', '04 서비스 품질', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 04 데이터 전송\r\n', '01 전송 방식', '02 오류 제어', '03 프레임 구조', '04 오류 검출 기법', '요약', '연습문제', '현장의 목소리 02', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 05 MAC 계층\r\n', '01 IEEE 802 시리즈', '02 CSMA/CD', '03 토큰 버스', '04 토큰 링', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 06 데이터 링크 계층\r\n', '01 프로토콜의 기초', '02 슬라이딩 윈도우 프로토콜', '03 HDLC 프로토콜', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 07 IP 프로토콜\r\n', '01 네트워크 계층의 기능', '02 라우팅 프로토콜', '03 IP 프로토', '요약', '연습문제', '현장의 목소리 03', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 08 네트워크 계층\r\n', '01 IPv6 프로토콜', '02 이동 IP 프로토콜', '03 제어용 프로토콜', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 09 TCP 프로토콜\r\n', '01 전송 계층의 기능', '02 TCP의 헤더 구조', '03 TCP의 동작 원리', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 10 전송 계층\r\n', '01 UDP 프로토콜', '02 RTP 프로토콜', '03 OSI TP 프로토콜', '요약', '연습문제', '현장의 목소리 04', '\r\n\t\t\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\t\t\t\t\t\tChapter 11 상위 계층\r\n', '01 상위 계층의 이해', '02 세션 계층', '03 표현 계층', '04 응용 계층', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 12 네트워크 프로그래밍\r\n', '01 소켓의 주소 체계', '02 소켓 시스템 콜', '03 클라이언트ㆍ서버 프로그래밍', '\xa0', '요약', '연습문제', '현장의 목소리 05', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 13 웹\r\n', '01 웹의 구조', '02 HTML의 기초', '03 HTTP 프로토콜', '04 CGI', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 14 DNS\r\n', '01 주소의 변환', '02 네임 스페이스', '03 네임 서버와 해석기', '04 DNS 프로토콜', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 15 전자 메일\r\n', '01 사용자 환경', '02 시스템 구조', '03 SMTP 프로토콜', '04 POP 서비스', '요약', '연습문제', '현장의 목소리 06', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 16 파일 전송\r\n', '01 FTP 응용 프로그램', '02 FTP 프로토콜', '03 TFTP 프로토콜', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 17 암호화와 네트워크 보안\r\n', '01 암호화의 이해', '02 암호화 시스템', '03 보안 프로토콜', '요약', '연습문제', '\xa0', '참고문헌', '찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B6129400746', 'title': 'IT CookBook, 우분투 리눅스(3판)', 'price': '34,000', 'content': ['', '\r\n\t\t\t\t\t\tPART 01 리눅스의 기본\r\n', '\xa0', '\r\n\t\t\t\t\t\tChapter 01 리눅스 설치와 기본 사용법\r\n', '00 개요', '01 리눅스 기초', '02 리눅스 실습 환경 구축', '03 리눅스 윈도 기본 사용법', '04 리눅스 명령 사용법', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 02 디렉터리와 파일 사용법\r\n', '00 개요', '01 리눅스의 파일과 디렉터리', '02 디렉터리 관련 명령', '03 파일 관련 명령', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 03 문서 편집\r\n', '00 개요', '01 리눅스의 문서 편집기', '02 vi 사용법', '03 vi 환경 설정', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 04 셸 사용법\r\n', '00 개요', '01 셸의 기능과 종류', '02 셸 기본 사용법', '03 입출력 방향 변경', '04 배시셸 환경 설정', '05 앨리어스와 히스토리', '06 프롬프트 설정', '07 환경 설정 파일', '연습문제', '\r\n\t\t\t\t\t\t\r\n', '\r\n\t\t\t\t\t\tChapter 05 파일 접근 권한 관리\r\n', '00 개요', '01 파일 속성', '02 파일 접근 권한', '03 기호를 이용한 파일 접근 권한 변경', '04 숫자를 이용한 파일 접근 권한 변경', '05 기본 접근 권한 설정', '06 특수 접근 권한 설정', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 06 프로세스 관리\r\n', '00 개요', '01 프로세스의 개념', '02 프로세스 관리 명령', '03 포그라운드ㆍ백그라운드 프로세스와 작업 제어', '04 작업 예약', '연습문제', '\xa0', '\xa0', '\r\n\t\t\t\t\t\tPART 02 리눅스 시스템 관리\r\n', '\xa0', '\r\n\t\t\t\t\t\tChapter 07 파일 시스템과 디스크 관리\r\n', '00 개요', '01 리눅스 파일 시스템 종류', '02 리눅스 파일 시스템 구조', '03 파일 시스템 마운트', '04 디스크 추가 설치', '05 디스크 관리', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 08 리눅스의 부팅과 종료\r\n', '00 개요', '01 리눅스 시스템의 부팅', '02 systemd 서비스', '03 리눅스 시스템의 종료', '04 데몬 프로세스', '05 부트 로더', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 09 소프트웨어 관리\r\n', '00 개요', '01 우분투 패키지의 개요', '02 우분투 패키지 설치', '03 스냅 패키지 설치', '04 파일 아카이브와 압축', '05 소프트웨어 컴파일', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 10 사용자 관리\r\n', '00 개요', '01 사용자 계정 관련 파일', '02 사용자 계정 관리 명령', '03 그룹 관리 명령', '04 사용자 정보 관리 명령', '05 디스크 사용량(쿼터) 설정', '연습문제', '\xa0', '\xa0', '\r\n\t\t\t\t\t\tPART 03 리눅스 네트워크 서비스 관리\r\n', '\xa0', '\r\n\t\t\t\t\t\tChapter 11 네트워크 설정\r\n', '00 개요', '01 네트워크 기초', '02 네트워크 설정', '03 호스트 이름 설정', '04 네트워크 상태 확인', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 12 원격 접속과 FTP\r\n', '00 개요', '01 텔넷과 SSH', '02 파일 송수신', '03 메일 송수신', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 13 DB 서버와 웹 서버\r\n', '00 개요', '01 데이터베이스', '02 MariaDB 설치와 사용', '03 웹 서버 설치와 사용', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 14 NFS와 삼바\r\n', '00 개요', '01 NFS 설치와 운영', '02 삼바 설치와 활용', '연습문제', '\r\n\t\t\t\t\t\t\r\n', '\xa0', '\r\n\t\t\t\t\t\tPART 04 리눅스 보안 및 프로젝트\r\n', '\xa0', '\r\n\t\t\t\t\t\tChapter 15 리눅스 보안의 기초\r\n', '00 개요', '01 정보 보안의 기초', '02 시스템 로그', '03 방화벽 관리', '04 보안 관리 도구', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 16 프로젝트\r\n', '01 프로젝트의 개요와 환경 구성', '02 프로젝트 시나리오', '연습문제', '\xa0', '찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B7738896383', 'title': '거시경제학(3판)', 'price': '36,000', 'content': ['', '\r\n\t\t\t\t\t제1편 거시경제학의 기초\r\n', '제1장 거시경제학의 주요 관심사', '제2장 거시경제의 측정 Ⅰ: 국민소득', '제3장 거시경제의 측정 Ⅱ: 인플레이션과 실업', '제4장 국민소득의 생산과 분배', '\r\n\t\t\t\t\t\t부록: 생산함수와 관계된 주요 거시경제변수\r\n', '제5장 지출 측면의 국민소득', '\r\n\t\t\t\t\t\t부록: 개방경제의 순환 과정\r\n', '제1편 요약', '제1편 연습문제', '\xa0', '\r\n\t\t\t\t\t제2편 국민소득 결정이론: 단순모형\r\n', '제6장 고전학파모형', '제7장 단순 케인즈모형', '제8장 실업: 고전학파 대 케인즈', '\r\n\t\t\t\t\t\t부록: 우리나라의 실업률과 경제성장률 추이 86\r\n', '제2편 요약', '제2편 연습문제', '\xa0', '\r\n\t\t\t\t\t제3편 화폐와 거시경제\r\n', '제9장 화폐와 금융시장', '제10장 화폐와 물가', '제11장 이자율: 고전학파 대 케인즈', '\r\n\t\t\t\t\t\t부록: 예상인플레이션과 물가 126\r\n', '제3편 요약', '제3편 연습문제', '\xa0', '\r\n\t\t\t\t\t제4편 거시경제의 수요 측면\r\n', '제12장 IS-LM 곡선의 도출', '제13장 IS-LM 모형과 재정·통화정책', '\r\n\t\t\t\t\t\t부록: 코로나 경제 위기에 대한 IS-LM 분석\r\n', '제14장 물가, 예상인플레이션과 IS-LM 모형', '\r\n\t\t\t\t\t\t부록: 수식으로 표현한 IS-LM 모형\r\n', '제4편 요약', '제4편 연습문제', '\xa0', '\r\n\t\t\t\t\t제5편 총수요·총공급모형\r\n', '제15장 단기와 장기', '제16장 총공급곡선의 도출 Ⅰ: 착오와 불완전정보', '제17장 총공급곡선의 도출Ⅱ: 임금과 가격의 경직성', '\r\n\t\t\t\t\t\t부록: 불완전경쟁과 총공급곡선\r\n', '제18장 기대형성과 총공급곡선', '제19장 총수요·총공급 충격과 경기변동', '제20장 필립스곡선', '\r\n\t\t\t\t\t\t부록: 우리나라의 필립스곡선과 오쿤의 법칙 248\r\n', '제5편 요약', '제5편 연습문제', '\xa0', '\r\n\t\t\t\t\t제6편 경제성장\r\n', '제21장 경제성장의 요인과 성장회계', '\r\n\t\t\t\t\t\t부록: 우리나라의 성장회계\r\n', '제22장 자본축적과 솔로우모형', '\r\n\t\t\t\t\t\t부록: 고령화와 경제성장률\r\n', '제23장 기술진보와 솔로우모형', '제24장 내생적 성장이론', '제6편 요약', '제6편 연습문제', '\xa0', '\r\n\t\t\t\t\t제7편 거시경제학의 미시경제적 기초\r\n', '제25장 소비이론 Ⅰ: 기본모형', '제26장 소비이론 Ⅱ: 다기간 선택', '제27장 소비이론 Ⅲ: 재정정책과 소비', '\r\n\t\t\t\t\t\t부록: 우리나라 소비 변동의 특성\r\n', '제28장 투자이론 Ⅰ: 기본모형', '\r\n\t\t\t\t\t\t부록: 자본의 한계효율과 투자의 한계효율\r\n', '제29장 투자이론 Ⅱ: 투자의 불안정성', '\r\n\t\t\t\t\t\t부록: 우리나라 설비투자 변동의 특성\r\n', '제30장 화폐의 공급', '제31장 화폐의 수요', '\r\n\t\t\t\t\t\t부록: 우리나라 화폐수요함수의 특성\r\n', '제7편 요약', '제7편 연습문제', '\xa0', '\r\n\t\t\t\t\t제8편 개방거시경제\r\n', '제32장 국제수지와 환율', '\r\n\t\t\t\t\t\t부록: 마샬-러너 조건의 도출\r\n', '제33장 구매력평가와 이자율평가', '\r\n\t\t\t\t\t\t부록: 국가위험도와 이자율평가\r\n', '제34장 개방거시경제모형: 수요 측면', '제35장 환율과 물가의 조정, 외환위기, 환율제도의 선택', '\r\n\t\t\t\t\t\t부록: 관리변동환율과 불태화 외환시장 개입\r\n', '제8편 요약', '제8편 연습문제', '\xa0', '\r\n\t\t\t\t\t제9편 경기변동과 안정화정책에 대한 논쟁\r\n', '제36장 새고전학파의 도전', '제37장 RBC 이론', '제38장 새케인즈학파의 주요 이론', '제39장 이자율 준칙과 IS-MP 모형', '제40장 안정화정책: 종합', '\r\n\t\t\t\t\t\t부록: 정부부채 비율의 계산\r\n', '제9편 요약', '제9편 연습문제', '\xa0', '부록 연습문제(선택형, 서술형) 해답 및 해설', '찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B4354575770', 'title': '생각하는 힘이 붙는 첫 숨은그림찾기', 'price': '6,300', 'content': ['', '\xa0']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B1959656080', 'title': '실용적 접근 방식의 경영학원론(10판)', 'price': '39,000', 'content': ['', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tPART 01 도입\r\n', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCHAPTER 01 경영자\r\n', 'SECTION 01 경영의 의미\xa0', 'SECTION 02 경영의 네 가지 주요 기능', 'SECTION 03 경영의 수준과 분야', 'SECTION 04 경영자의 역할', 'SECTION 05 경영자에게 필요한 스킬', 'SECTION 06 경영자가 해결해야 할 일곱 가지 과제', 'SECTION 07 커리어 준비', 'SECTION 08 커리어 준비 실천', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCHAPTER 02 경영 이론\r\n', 'SECTION 01 현대 경영 이론의 탄생 배경', 'SECTION 02 고전 이론', 'SECTION 03 행동주의 관점', 'SECTION 04 계량적 관점', 'SECTION 05 시스템 관점', 'SECTION 06 상황론적 관점', 'SECTION 07 최신 접근법', 'SECTION 08 커리어 준비 실천', '\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tPART 02 경영 환경\r\n', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCHAPTER 03 경영 환경과 윤리적 책임\r\n', 'SECTION 01 비즈니스의 목적', 'SECTION 02 조직 내부의 이해관계자', 'SECTION 03 조직 외부의 이해관계자', 'SECTION 04 경영자에게 요구되는 윤리적 책임', 'SECTION 05 경영자에게 요구되는 사회적 책임', 'SECTION 06 기업 지배 구조', 'SECTION 07 커리어 준비 실천', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCHAPTER 04 국제 경영\r\n', 'SECTION 01 세계화', 'SECTION 02 국제 경영과 글로벌 경영자', 'SECTION 03 기업의 해외 시장 진출 방식', 'SECTION 04 지역 경제의 협력과 경쟁', 'SECTION 05 문화적 차이 이해의 중요성', 'SECTION 06 커리어 준비 실천', '\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tPART 03 계획\r\n', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCHAPTER 05 경영 계획\r\n', 'SECTION 01 계획과 전략', 'SECTION 02 계획의 기초', 'SECTION 03 목표와 계획', 'SECTION 04 목표의 일관성', 'SECTION 05 계획·통제 주기', 'SECTION 06 커리어 준비 실천', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCHAPTER 06 전략 경영\r\n', 'SECTION 01 전략적 포지셔닝과 전략의 수준', 'SECTION 02 전략 경영 프로세스', 'SECTION 03 현상황 진단', 'SECTION 04 기업 수준 전략', 'SECTION 05 사업 수준 전략', 'SECTION 06 기능 수준 전략', 'SECTION 07 커리어 준비 실천', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCHAPTER 07 개인과 집단 의사 결정\r\n', 'SECTION 01 합리적인 의사 결정과 비합리적인', 'SECTION 02 윤리적인 의사 결정', 'SECTION 03 증거 기반 의사 결정과 자료 분석', 'SECTION 04 인공 지능을 활용한 의사 결정', 'SECTION 05 의사 결정의 네 가지 스타일', 'SECTION 06 의사 결정의 열 가지 편향', 'SECTION 07 집단 의사 결정', 'SECTION 08 커리어 준비 실천', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tPART 04 조직\r\n', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCHAPTER 08 조직 문화와 조직 구조\r\n', 'SECTION 01 전략에 맞추는 조직 문화, 조직 구조, HR 제도', 'SECTION 02 조직 문화', 'SECTION 03 조직 문화의 변화 과정', 'SECTION 04 조직 구조', 'SECTION 05 조직 구조의 유형', 'SECTION 06 커리어 준비 실천', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCHAPTER 09 인적 자원 관리\r\n', 'SECTION 01 전략적 인적 자원 관리', 'SECTION 02 모집과 채용', 'SECTION 03 보상과 복리 후생', 'SECTION 04 학습과 개발', 'SECTION 05 성과 관리', 'SECTION 06 승진, 전출, 징계, 해고', 'SECTION 07 노사 관계', 'SECTION 08 커리어 준비 실천', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCHAPTER 10 조직 변화와 혁신\r\n', 'SECTION 01 조직 변화', 'SECTION 02 조직 변화의 이론', 'SECTION 03 조직 개발', 'SECTION 04 조직 혁신', 'SECTION 05 조직 변화의 장애 요인', 'SECTION 06 커리어 준비 실천', '\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tPART 05 리드\r\n', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCHAPTER 11 개인 차이와 행동\r\n', 'SECTION 01 성격과 개인 행동', 'SECTION 02 가치, 태도, 행동', 'SECTION 03 지각과 개인 행동', 'SECTION 04 직무 태도와 행동', 'SECTION 05 인력의 다양성', 'SECTION 06 스트레스와 개인 행동 이해', 'SECTION 07 커리어 준비 실천', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCHAPTER 12 직원 동기 부여\r\n', 'SECTION 01 동기 부여', 'SECTION 02 동기 부여의 내용 이론', 'SECTION 03 동기 부여의 과정 이론', 'SECTION 04 동기 부여를 위한 직무 설계', 'SECTION 05 동기 부여를 위한 강화 이론', 'SECTION 06 동기 부여를 위한 보상', 'SECTION 07 커리어 준비 실천', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCHAPTER 13 집단과 팀\r\n', 'SECTION 01 집단과 팀', 'SECTION 02 집단과 팀의 개발 과정', 'SECTION 03 효과적인 팀 구축', 'SECTION 04 갈등 관리', 'SECTION 05 커리어 준비 실천', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCHAPTER 14 권력, 영향, 그리고 리더십\r\n', 'SECTION 01 권력과 영향', 'SECTION 02 리더십의 특성 이론', 'SECTION 03 리더십의 행동 이론', 'SECTION 04 리더십의 상황 이론', 'SECTION 05 거래적 리더십과 변혁적 리더십', 'SECTION 06 리더십의 최근 이론', 'SECTION 07 커리어 준비 실천', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCHAPTER 15 의사소통\r\n', 'SECTION 01 의사소통의 의미와 과정', 'SECTION 02 의사소통의 경로', 'SECTION 03 의사소통의 장애물 ...
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B5171715268', 'title': '인피니티', 'price': '17,820', 'content': ['', '서문 | 과학이 허구를 넘어설 때\xa0', '들어가는 말 | 무한에 대하여', '우주의 무한 | 우주는 지금 몇 시일까\xa0', '양자의 무한 | 환영으로 이루어진 세계', '에필로그 | 진공의 숨결\xa0', '용어설명', '참고문헌']}

# %% [markdown]
# - python_crawler_5.ipynb실습

# %%
import requests
import lxml.html
import re

# %% [markdown]
# - 전체 페이지 크롤링을 위해 main() 함수의 for 구문에서 break를 제거
# - 대상 서버에 부하를 주지 않은 상태에서 크롤링을 위해 time 모듈을 import 및 time.sleep(1)을 넣어 1초 동안 대기

# %%
def main():
    # 여러 페이지에서 크롤링을 위해 Session 사용
    session = requests.Session()  
    # scrape_list_page() 함수를 호출해서 제너레이터를 추출
    response = session.get('http://www.hanbit.co.kr/store/books/new_book_list.html')
    urls = scrape_list_page(response)
    for url in urls:
        response = session.get(url)  # Session을 사용해 상세 페이지를 추출
        ebook = scrape_detail_page(response)  # 상세 페이지에서 상세 정보를 추출
        print(ebook)  # 상세 정보 출력

# %%
def scrape_list_page(response):
    root = lxml.html.fromstring(response.content)
    root.make_links_absolute(response.url)
    for a in root.cssselect('.view_box .book_tit a'):
        url = a.get('href')
        yield url

# %% [markdown]
# - 목차에 포함돼 있는 공백을 제거할 수 있는 normalize_space() 함수 정의
# - List Comprehension 구문에 조건을 추가해서 빈 문자열을 제거

# %%
def scrape_detail_page(response):
    """
    상세 페이지의 Response에서 책 정보를 dict로 추출
    """
    root = lxml.html.fromstring(response.content)
    ebook = {
        'url': response.url,
        'title': root.cssselect('.store_product_info_box h3')[0].text_content(),
        'price': root.cssselect('.pbr strong')[0].text_content(),
        'content': [normalize_spaces(p.text_content())
            for p in root.cssselect('#tabs_3 .hanbit_edit_view p')
            if normalize_spaces(p.text_content()) != '']
    }
    return ebook

# %%
def normalize_spaces(s):
    """
    연결된 공백을 하나의 공백으로 변경
    """
    return re.sub(r'\s+', ' ', s).strip()

# %%
if __name__ == '__main__':
    main()
# Out:
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B3178834938', 'title': '받침 없는 한글 동화 : 4권 세트', 'price': '49,680', 'content': ['<1편>', '이렇게 읽어요', '1. 무시무시 마녀가 이사 와!', '2. 아기 고래 뿌우의 노래', '<2편>', '이렇게 읽어요', '1. 도, 도, 도깨비다!', '2. 느티나무 아파트', '<3편>', '이렇게 읽어요', '1. 바쁘다 바빠 너구리 바빠', '2. 꼬마 지우개 마구마구', '<4편>', '이렇게 읽어요', '1. 도깨비 파자마 파티', '2. 꼬마 두루미 뚜루']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B6084607806', 'title': '받침 없는 한글 동화 : 도, 도, 도깨비다!', 'price': '12,420', 'content': ['이렇게 읽어요', '1. 도, 도, 도깨비다!', '2. 느티나무 아파트']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B8948111854', 'title': '받침 없는 한글 동화 : 도깨비 파자마 파티', 'price': '12,420', 'content': ['이렇게 읽어요', '1. 도깨비 파자마 파티', '2. 꼬마 두루미 뚜루']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B8661740335', 'title': '받침 없는 한글 동화 : 무시무시 마녀가 이사 와!', 'price': '12,420', 'content': ['이렇게 읽어요', '1. 무시무시 마녀가 이사 와!', '2. 아기 고래 뿌우의 노래']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B1382037871', 'title': '받침 없는 한글 동화 : 바쁘다 바빠 너구리 바빠', 'price': '12,420', 'content': ['이렇게 읽어요', '1. 바쁘다 바빠 너구리 바빠', '2. 꼬마 지우개 마구마구']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B2847674054', 'title': '리얼 몽골 [2022~2023 최신판]', 'price': '16,200', 'content': ['작가의 말', '몽골 지역 구분', '구글 지도 활용', 'PART 01 한눈에 보는 몽골', '한눈에 보는 몽골', '숫자로 보는 몽골', '몽골 기본 정보', '몽골 문화와 에티켓', '몽골 연중 날씨', '몽골 4색 테마 여행', '몽골 여행 키워드 10', '몽골 필수 여행지 10', '몽골 문화 & 역사', '추천 여행 코스', '완전 정복 2주 코스', '고비 사막 1주 코스', '홉스골 10일 코스', '울란바토르 알짜배기 코스', '테렐지 1박 2일 코스', 'PART 02 몽골을 가장 멋지게 여행하는 방법', '테마 여행', '액티비티', '몽골 동물', '전통 공연', '종교 문화', '불교 사원', '박물관 & 미술관', '나담 축제', '차강사르', '미식 여행', '전통 음식', '몽골리안 바비큐 & 핫팟', '럭셔리 레스토랑', '라운지 바 & 클럽', '몽골 맥주 & 보드카', '몽골 베이커리', '몽골 전통 음료', '쇼핑 여행', '여행 기념품점', '추천 기념품', '마트 & 드럭스토어 아이템', '캐시미어 아웃렛', '백화점 & 쇼핑몰', '전통시장 & 대형마트', 'PART 03 쉽고 즐거운 여행 준비', '준비 편', '몽골 여행 계획하기', '여행 준비 캘린더', '투어 차량 선택 노하우', '여행사 선정 방법', '은하수 촬영 꿀팁', '몽골 여행 준비물', '웹사이트 & 애플리케이션', '실전 편', '몽골 입국 절차', '칭기즈칸 국제공항', '울란바토르 시티투어 버스', '몽골 종단 철도', '환전 및 유심 카드', '[REAL GUIDE] 몽골 화폐', '추천 장보기 리스트', '몽골 여행 생활 가이드', '몽골 숙소의 모든 것', 'PART 04 진짜 몽골을 만나는 시간', '구역별로 만나는 몽골', '몽골 여행의 시작 울란바토르', '울란바토르 대중교통', 'SECTION A 울란바토르 중심부', '상세 지도', '추천 스폿', 'SECTION B 울란바토르 서남부', '상세 지도', '추천 스폿', '[REAL GUIDE]', '숨은 한국 찾기', 'SECTION C 울란바토르 동부', '상세 지도', '추천 스폿', '초원 위 힐링 여행지 테렐지 국립공원', '상세 지도', '가는 방법', '추천 스폿', '[REAL GUIDE]', '13세기 마을 테마 공원', '전통가옥 게르', '몽골 여행의 하이라이트 고비 사막', '상세 지도', '추천 스폿', '[REAL GUIDE]', '낙타 체험 & 모래 썰매', '몽골의 푸른 보석 홉스골', '상세 지도', '추천 스폿', '[REAL GUIDE]', '쳉헤르의 5대 온천', '홉스골 호수', '승마·ATV·수중 액티비티 체험', 'INDEX']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B4162156367', 'title': '오늘도 시작하지 못하는 당신을 위해', 'price': '14,850', 'content': ['프롤로그', '1장 완벽주의자의 탄생', '당신은 완벽주의자인가요?', ': 저는 완벽주의자가 아니에요', ': 이론 속 완벽주의자 유형', '우리는 어쩌면 대부분 완벽주의자', ': 생활 속 완벽주의자 유형', '-회피형 완벽주의자', '-감독형 완벽주의자', '-자책형 완벽주의자', '-안정형 완벽주의자', '2장 완벽주의, 스스로 만든 정신적 감옥', '우리는 모두 완벽을 강요당한다', ': 성과주의 문화가 낳은 괴물', ': 1등이 되면 고민은 끝이라는 착각', ': 온라인 세상으로 맞이한 또 다른 완벽주의', ': 불안과 우울, 그 너머에 있는 마음', '완벽주의자가 빠지기 쉬운 네 가지 함정', ': 지금 당장 버려야 할 완벽주의 생각 습관', '-당위성(should)의 오류', '-흑백논리의 오류', '-과잉(지나친) 일반화', '-재앙화(파국화) 사고', '3장 완벽주의 성향이 높은 편입니다', '완벽주의가 삶에 지장을 주려 할 때', ': 완벽주의 성향을 파악하는 척도', ': 완벽주의자의 성격', ': 나는 이만하면 괜찮은 완벽주의자?', '완벽주의 늪에 빠진 사람들', ': 양육 환경으로 완벽주의가 대물림된다', ': 평가에 민감한 사람들', ': 타인의 인정이 삶의 목표가 될 수는 없다', '완벽하려는 강박이 불러오는 이상 증세', ': 완벽주의자가 감정을 대하는 방식', ': 완벽주의자를 누르고 있는 감정들', '-죄책감과 수치심', '-걱정과 불안', '-우울과 슬픔', ': 완벽주의자가 낳은 질병들', '-강박장애', '-섭식장애', '-번아웃', '-무대 공포증', '4장 완벽주의의 균형을 찾아서', '완벽주의라는 허상', ': 낮은 완벽주의, 높은 성취감', ': 완벽주의자에게 진짜 필요한 능력', '서로가 서로를 도울 수 있다', ': 완벽주의자가 쉽게 우울해지는 이유', ': 완벽주의자를 둘러싼 관계 재조명', '-부모와 자녀', '-부부 혹은 연인', '-리더와 조직원', '5장 완벽주의 성향이 높은 편입니다', '1주차_인정하라', ': 성과를 가로막는 진짜 장애물을 파악하라', ': 인정하는 연습, 나는 완벽주의자입니다', '2주차_기준을 바꾸라', ': 완벽주의자들의 비현실적인 기준', ': 기준을 바꾸는 연습', '3주차_두려움의 뿌리를 찾아라', ': 부정적인 감정 들여다보기', ': 혼자서 자동적 사고를 찾아보고 싶을 때', '4주차_실수에 대한 두려움을 버리고 계속 시도하기', ': 실수를 두려워하지 않는 사람은 없다', ': 실수를 기회로 바꾸는 방법', '5주차_완벽하지 않아서 행복한 사람들', ': 완벽주의를 조절하는 현실적인 기법', ': 내 안의 안정형 완벽주의를 키우자', '6장 완벽을 포기하고 완벽에 가까워진 사람들', '행복한 똑똑이가 되는 진짜 비결', ': 진짜 필요한 능력, 자기 효능감', ': 타인이 아닌 자신을 위한 노력', '두 마리 토끼를 모두 잡으려면', ': 역할 과부하에 시달리는 엄마들', ': 버거운 말을 거절하는 연습', '유니콘 기업의 건강한 조직 문화', ': 조직이 개인 퍼포먼스를 돕는 이유', ': 완벽하지 않은 조직문화의 가치', '운동선수도 피할 수 없는 완벽주의', ': 운동의 흐름을 방해하는 큰 위기, 입스', ': 심리적 불안이 일으킨 신체적 증상', ': 맹목적인 경쟁심에 사로잡히지 않으려면', '에필로그', '주', '부록: 완벽주의 극복 5주 프로그램 워크북']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B5156679966', 'title': 'IT CookBook, 원리로 이해하는 전력전자공학(2판)', 'price': '30,000', 'content': ['CHAPTER 01 전력전자공학의 기초', '1.1 개요', '1.2 기초 회로이론', '연습문제', 'CHAPTER 02 전력용 반도체 스위치', '2.1 개요', '2.2 다이오드', '2.3 전력용 트랜지스터', '2.4 사이리스터', '2.5 MOSFET', '2.6 IGBT', '2.7 와이드 밴드 갭 소자', '2.8 전력용 반도체 스위치 비교', '2.9 추가 부품', '연습문제', 'CHAPTER 03 정류기와 AC-AC 컨버터', '3.1 개요', '3.2 단상 반파 정류기', '3.3 단상 전파 정류기', '3.4 3상 반파 정류기', '3.5 3상 전파 정류기', '3.6 AC-AC 컨버터', '3.7 전원 측 인덕턴스의 영향', '연습문제', 'CHAPTER 04 비절연형 DC-DC 컨버터', '4.1 개요', '4.2 강압형 컨버터', '4.3 승압형 컨버터', '4.4 승강압형 컨버터', '4.5 비절연형 DC-DC 컨버터의 설계', '연습문제', 'CHAPTER 05 절연형 DC-DC 컨버터', '5.1 개요', '5.2 플라이백 컨버터 5.2', '5.3 포워드 컨버터 5.3', '5.4 푸시풀 컨버터', '5.5 하프 브리지 컨버터', '5.6 풀 브리지 컨버터', '5.7 역률 개선 회로', '연습문제', 'CHAPTER 06 인버터', '6.1 개요', '6.2 단상 하프 브리지 인버터', '6.3 단상 풀 브리지 인버터', '6.4 3상 전압원 인버터', '6.5 3상 전류원 인버터', '연습문제', 'CHAPTER 07 공진형 컨버터', '7.1 개요', '7.2 준 공진형 컨버터', '7.3 부하 공진형 컨버터', '7.4 위상천이 풀 브리지 컨버터', '연습문제', 'CHAPTER 08 고전압 대용량 전력변환', '8.1 개요', '8.2 다이오드 클램프 멀티레벨 인버터', '8.3 캐스케이디드 H-브리지 인버터', '8.4 모듈러 멀티레벨 컨버터', '8.5 다중 펄스 다이오드 정류기', '연습문제', 'CHAPTER 09 신재생에너지', '9.1 개요', '9.2 풍력에너지 시스템', '9.3 태양광에너지 시스템', '9.4 연료전지 시스템', '9.5 에너지 저장 시스템', '연습문제', 'CHAPTER 10 전력전자 응용', '10.1 개요', '10.2 유연 송전시스템(FACTS)', '10.3 마이크로그리드와 직류 송배전 기술', '10.4 반도체 변압기', '10.5 전기추진 응용', '10.6 핵융합 발전', '10.7 가전 응용', '연습문제']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B6189263297', 'title': '트러스트', 'price': '16,920', 'content': ['감사의 말 | 이 책에서 다룰 내용', 'Chapter 1. 신뢰의 역사', '생물학 | 선물 | 종교 | 중세의 시장과 국제무역 | 법률', 'Chapter 2. 전문기관에 대한 신뢰', '정치인 | 미디어 | 의학에 대한 신뢰 | 과학 | 기후변화', 'Chapter 3. 서로 신뢰하기', '낯선 사람에 대한 신뢰 | 자신에 대한 신뢰 | 사과와 비난 | 정체성, 존엄성, 프라이버시', 'Chapter 4. 신뢰의 경제학', '신뢰에 대한 경제학 서적을 읽는 이유 | 내가 신뢰에 대한 경제학 책을 쓴 이유 | 신뢰에 대한 경제학자의 생각 | 경제학적 신뢰이론 | 인과관계와 실증경제학자의 방법론', 'Chapter 5. 현대경제와 신뢰', '화폐 | 투자와 금융 | 계약 | 직장 | 브랜드 | 시장경제와 신뢰의 미래: 공유 경제와 블록체인', 'Chapter 6. 결론', '주 | 찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B4813114979', 'title': '구글 앱스 스크립트 완벽 가이드', 'price': '36,000', 'content': ['Chapter 1 구글 앱스 스크립트 기본 지식', '1.1 구글 앱스 스크립트', '1.2 구글 앱스와 구글 워크스페이스', '1.3 GAS로 조작할 수 있는 애플리케이션', '1.4 GAS 학습 시 주의할 점', 'Chapter 2 스크립트 편집기와 대시보드', '2.1 헬로! GAS', '2.2 프로젝트와 스크립트', '2.3 스크립트 편집기의 편집 기능', '2.4 로그와 디버그', '2.5 권한과 허가', '2.6 지원 메뉴와 레퍼런스', 'Chapter 3 기본 문법', '3.1 자바스크립트 기초', '3.2 변수와 상수', '3.3 데이터 타입', '3.4 배열', '3.5 객체', '3.6 산술 연산자와 대입 연산자', 'Chapter 4 제어문', '4.1 if문을 이용한 조건 분기', '4.2 조건식, 비교 연산자, 논리 연산자', '4.3 switch문을 이용한 다중 분기', '4.4 while문을 이용한 반복', '4.5 for문을 이용한 반복', '4.6 for...of문을 이용한 반복', '4.7 for...in문을 이용한 반복', '4.8 반복 처리 중단과 건너뛰기', '4.9 try...catch문과 예외 처리', 'Chapter 5 함수', '5.1 함수', '5.2 함수 리터럴', '5.3 스코프', 'Chapter 6 클래스와 객체', '6.1 객체, 속성, 메서드', '6.2 클래스와 인스턴스화', '6.3 메서드와 프로토타입', '6.4 정적 멤버', 'Chapter 7 자바스크립트의 내장 객체', '7.1 내장 객체', '7.2 수치 다루기 - Number 객체', '7.3 문자열 다루기 - String 객체', '7.4 배열 다루기 - Array 객체', '7.5 함수 다루기 - Function 객체', '7.6 날짜와 시간 다루기 - Date 객체', '7.7 정규 표현 다루기 - RegExp 객체', '7.8 예외 정보 얻기 - Error 객체', '7.9 수학 연산 실행하기 - Math 객체', '7.10 JSON 데이터 다루기 - JSON 객체', '7.11 객체 다루기 - Object 객체', '7.12 글로벌 함수', 'Chapter 8 스프레드시트', '8.1 Spreadsheet 서비스', '8.2 SpreadsheetApp 클래스', '8.3 스프레드시트 조작하기 - Spreadsheet 클래스', '8.4 시트 조작하기 - Sheet 클래스', '8.5 셀 범위 조작하기 - Range 클래스', '8.6 배열을 사용한 데이터 처리', '8.7 커스텀 함수', 'Chapter 9 지메일', '9.1 Gmail 서비스', '9.2 GmailApp 클래스', '9.3 스레드 얻기', '9.4 스레드 다루기 - GmailThread 클래스', '9.5 메시지 얻기', '9.6 메시지 다루기 - GmailMessage 클래스', 'Chapter 10 드라이브', '10.1 Drive 서비스', '10.2 DriveApp 클래스', '10.3 폴더 조작하기 - Folder 클래스', '10.4 파일 조작하기 - File 클래스', '10.5 폴더와 파일 컬렉션 조작하기', '10.6 폴더와 파일 공유 및 권한 조작하기', 'Chapter 11 캘린더', '11.1 Calendar 서비스', '11.2 CalendarApp 클래스', '11.3 캘린더 조작하기 - Calendar 클래스', '11.4 이벤트 조작하기 - CalendarEvent 클래스', 'Chapter 12 문서', '12.1 Document 서비스', '12.2 DocumentApp 클래스', '12.3 문서 조작하기 - Document 클래스', '12.4 섹션 조작하기', '12.5 단락 및 리스트 아이템 조작하기', '12.6 텍스트 객체 조작하기', '12.7 문자열 수정과 서식 설정', '12.8 문자열 찾기와 바꾸기', 'Chapter 13 프레젠테이션', '13.1 Slides 서비스', '13.2 SlidesApp 클래스', '13.3 프레젠테이션 조작하기 - Presentation 클래스', '13.4 프레젠테이션 조작하기 - Slide 클래스', '13.5 페이지 요소 조작하기', '13.6 텍스트 범위와 문자열 조작하기', 'Chapter 14 설문지', '14.1 Forms 서비스', '14.2 FormApp 클래스', '14.3 설문지 조작하기 - Form 클래스', '14.4 아이템 조작하기', 'Chapter 15 번역', '15.1 Language 서비스와 LanguageApp 클래스', 'Chapter 16 Base 서비스', '16.1 Base 서비스', '16.2 로그', '16.3 세션과 사용자', 'Chapter 17 사용자 인터페이스', '17.1 UI 조작과 UI 클래스', '17.2 다이얼로그', '17.3 메뉴', '17.4 스프레드시트 UI 확장하기', 'Chapter 18 파일과 데이터 조작', '18.1 Blob 객체', '18.2 첨부 파일 조작하기', 'Chapter 19 Utilities 서비스', '19.1 Utilities 서비스', '19.2 ZIP 파일과 CSV 파일', '19.3 날짜와 시간을 문자열로 바꾸기', 'Chapter 20 Properties 서비스', '20.1 속성 저장소', '20.2 Properties 서비스와 PropertiesService 클래스', '20.3 속성 저장소 읽고 쓰기 - Properties 클래스', 'Chapter 21 이벤트와 트리거', '21.1 심플 트리거', '21.2 인스톨러블 트리거', '21.3 이벤트 객체', '21.4 Script 서비스', 'Chapter 22 외부 서비스 접속', '22.1 Url Fetch 서비스', '22.2 HTTP 리퀘스트와 HTTP 리스폰스', '22.3 HTML, JSON에서 데이터 추출하기', 'Chapter 23 라이브러리', '23.1 라이브러리 이용하기', '23.2 라이브러리 만들기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B8806843023', 'title': '리얼 싱가포르 [2022~2023 최신판]', 'price': '16,200', 'content': ['작가의 말', '이 책의 사용법', 'PART 01 미리 보는 싱가포르', '한눈에 보는 싱가포르', '숫자로 보는 싱가포르', '싱가포르 여행 기본 정보', '싱가포르 명절 & 축제', '싱가포르 여행의 매력', '싱가포르 여행 버킷 리스트', '이건 꼭 먹자! 싱가포르 음식', '이건 꼭 사자! 싱가포르 아이템', '키워드로 읽는 싱가포르 역사', '알아두면 유용한 싱가포르 문화', '[REAL GUIDE]', '싱가포르 대중교통 이용하기', '파인다이닝 즐기기', '한정판 야경의 매력, 아이라이트 싱가포르', '센토사를 오가는 교통수단', '유니버설 스튜디오 싱가포르 예습하기', '싱가포르 4대 동물원 총정리', '여행의 마지막을 알뜰하게! GST 환급 받기', '공항 속 복합 쇼핑몰 주얼 창이 싱가포르', 'PART 02 싱가포르를 가장 멋지게 여행하는 방법', 'THEME', '레이저 쇼', '사원', '박물관', '전통 건축물', '현대 건축물', '시티 정글', '도서관 & 서점', '센토사의 명물', '루프톱 바', 'FOOD', '스타 셰프 레스토랑', '파인다이닝', '브런치 카페', '애프터눈 티', '호커 센터 & 푸드코트', '콘셉트 레스토랑', '로컬 맛집', '인스타그래머블 카페', '커피 맛집', '중국 음식', '싱가포르 베스트 바', 'SHOPPING', '오차드 로드 대표 쇼핑몰', '기념품 쇼핑', '개성 만점 편집숍', '로컬 디자이너 브랜드', '현지 마트', 'REAL COURSE GUIDE', '단기 집중 2박 3일 코스', '정석대로 핵심만 쏙쏙 3박 4일 코스', '느긋하게 즐기는 4박 5일 코스', '3박 4일 친구끼리 여행', '4박 5일 아이와 함께하는 가족 여행', '3박 4일 로맨틱 커플 여행', '3박 4일 식도락 여행', 'PART 03 진짜 싱가포르를 만나는 시간', 'AREA 1 올드 시티', '상세 지도', '추천 스폿', 'AREA 2 마리나 베이', '상세 지도', '추천 스폿', 'AREA 3 리버사이드', '상세 지도', '추천 스폿', 'AREA 4 오차드 로드', '상세 지도', '추천 스폿', 'AREA 5 차이나타운 & CBD', '상세 지도', '추천 스폿', 'AREA 6 부기스', '상세 지도', '추천 스폿', 'AREA 7 리틀 인디아', '상세 지도', '추천 스폿', 'AREA 8 센토사 & 하버프런트', '상세 지도', '추천 스폿', 'PART 04 개성 강한 주변 지역 여행', 'PLUS AREA 1 뎀시 힐', '지도와 추천 코스', '추천 스폿', 'PLUS AREA 2티옹바루', '지도와 추천 코스', '추천 스폿', 'PLUS AREA 3 카통', '지도와 추천 코스', '추천 스폿', 'PLUS AREA 4 홀랜드 빌리지', '지도와 추천 코스', '추천 스폿', 'PART 05 쉽고 즐거운 여행 준비', 'GUIDE 01 여행 준비 & 출입국', 'GUIDE 02 숙소']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B2859439220', 'title': '원소 이야기', 'price': '15,300', 'content': ['머리말: 현실을 요리하는 법', '1장 원소 사냥에 뛰어든 천재들', '2장 쪼개지지 않는 근원', '3장 원자 모형의 진화', '4장 원자는 어디에서 올까?', '5장 주기율표의 서막이 열리다', '6장 양자역학으로 해결된 주기율표', '7장 불안하면 터진다', '8장 연금술사의 꿈이 이루어지다', '9장 금속원소와 전기', '10장 산, 비금속원소, 빛', '11장 생명을 구성하는 모든 것이 주기율표에 있다', '12장 세상을 바꾼 원소들', '부록', '감사의 말', '주']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B1996635146', 'title': '핸즈온 데이터 시각화', 'price': '34,200', 'content': ['CHAPTER 0 서문', '0.1 왜 데이터 시각화인가', '0.2 무엇을 믿을 수 있을까요', '0.3 더 설득력 있는 그림', '0.4 진실의 여러 가지 그림자', '0.5 책의 구성', '0.6 마치며', '[PART I 기본 기술]', 'CHAPTER 1 스토리를 위한 도구 선택하기', '1.1 데이터 스토리 스케치하기', '1.2 도구를 선택할 때 고려해야 할 10가지 요소', '1.3 추천 도구', '1.4 패스워드 관리자 사용', '1.5 마치며', 'CHAPTER 2 스프레드시트 스킬 강화하기', '2.1 스프레드시트 도구 선택', '2.2 CSV 또는 ODS 형식으로 다운로드하기', '2.3 구글 시트 복사본 만들기', '2.4 구글 시트 공유하기', '2.5 구글 시트 업로드하고 변환하기', '2.6 구글 시트에서 주소 지오코딩하기', '2.7 구글 설문지로 데이터 수집하기', '2.8 데이터 정렬 및 필터', '2.9 수식을 사용해 계산하기', '2.10 피벗 테이블을 사용해 데이터 요약하기', '2.11 VLOOKUP을 사용해 열 매칭하기', '2.12 스프레드시트와 관계형 데이터베이스', '2.13 마치며', 'CHAPTER 3 데이터를 찾고 질문하기', '3.1 검색을 위한 질문 가이드', '3.2 공공 데이터와 개인 데이터', '3.3 민감한 데이터를 가리거나 집계하기', '3.4 오픈 데이터 저장소', '3.5 데이터 출처 남기기', '3.6 불량 데이터 인식하기', '3.7 데이터에 대해 질문하기', '3.8 마치며', 'CHAPTER 4 지저분한 데이터 정리하기', '4.1 구글 시트 스마트 클린업', '4.2 찾기 및 바꾸기', '4.3 행과 열 바꾸기', '4.4 데이터를 서로 다른 열로 나누기', '4.5 데이터를 한 열에 합치기', '4.6 타불라를 사용해 PDF에서 테이블 추출하기', '4.7 오픈리파인으로 데이터 정리하기', '4.8 마치며', 'CHAPTER 5 의미 있는 비교하기', '5.1 비교를 정확히 기술하기', '5.2 데이터 정규화하기', '5.3 편향된 비교 주의하기', '5.4 마치며', '[PART II 시각화 구축]', 'CHAPTER 6 차트 만들기', '6.1 차트 디자인 원칙', '6.2 구글 시트 차트', '6.3 막대 차트와 열 차트', '6.4 히스토그램', '6.5 원형 차트, 선 차트, 영역 차트', '6.6 데이터래퍼 차트', '6.7 주석이 달린 차트', '6.8 범위 차트', '6.9 분산형 차트와 버블 차트', '6.10 태블로 퍼블릭 차트', '6.11 태블로 퍼블릭으로 만드는 분산형 차트', '6.12 필터링된 선 차트', '6.13 마치며', 'CHAPTER 7 데이터를 지도로 시각화하기', '7.1 지도 디자인 원칙', '7.2 코로플레스 색상과 간격 디자인', '7.3 코로플레스 지도 데이터 정규화하기', '7.4 구글 내 지도로 만드는 포인트 지도', '7.5 데이터래퍼로 만드는 심벌 포인트 지도', '7.6 데이터래퍼로 만드는 코로플레스 지도', '7.7 태블로 퍼블릭으로 만드는 코로플레스 지도', '7.8 소크라타 오픈 데이터로 만드는 실시간 지도', '7.9 마치며', 'CHAPTER 8 테이블을 활용한 시각화', '8.1 테이블 디자인 원칙', '8.2 스파크라인으로 만드는 데이터래퍼 테이블', '8.3 기타 테이블 생성 도구', '8.4 마치며', 'CHAPTER 9 웹에 임베딩하기', '9.1 정적 이미지와 대화형 iframe', '9.2 임베드 코드 또는 iframe 태그 가져오기', '9.3 코드 또는 iframe을 웹사이트에 붙여넣기', '9.4 마치며', '[PART III 코드 템플릿과 고급 도구]', 'CHAPTER 10 깃허브로 코드 수정하고 호스트하기', '10.1 간단한 리플릿 맵 템플릿 복사, 수정, 호스팅하기', '10.2 깃허브 페이지 링크를 iframe으로 변환하기', '10.3 깃허브에 새로운 레포 만들고 파일 업로드하기', '10.4 깃허브 데스크톱과 아톰 텍스트 편집기를 사용해 효율적인 코딩하기', '10.5 마치며', 'CHAPTER 11 Chart.js와 하이차트 템플릿', '11.1 Chart.js로 만드는 막대 또는 열 차트', '11.2 Chart.js로 만드는 오류 바', '11.3 Chart.js로 만드는 선 차트', '11.4 하이차트로 만드는 주석이 달린 선 차트', '11.5 Chart.js로 만드는 분산형 차트', '11.6 Chart.js로 만드는 버블 차트', '11.7 마치며', 'CHAPTER 12 리플릿 맵 템플릿', '12.1 구글 시트로 만드는 리플릿 맵', '12.2 구글 시트로 만드는 리플릿 스토리맵', '12.3 구글 시트 API 키 가져오기', '12.4 CSV 데이터로 만드는 리플릿 맵', '12.5 CSV 데이터로 만드는 리플릿 히트맵 포인트', '12.6 검색 가능한 리플릿 포인트 지도', '12.7 오픈 데이터 API로 만드는 리플릿 맵', '12.8 마치며', 'CHAPTER 13 지도 데이터 변환하기', '13.1 지리 공간 데이터와 GeoJSON', '13.2 GeoJSON 경계 파일 찾기', '13.3 GeoJson.io를 사용해 그리고 편집하기', '13.4 맵셰이퍼를 사용해 편집하고 병합하기', '13.5 압축된 KMZ를 KML로 변환하기', '13.6 맵 워퍼로 지오레퍼런스하기', '13.7 미국 통계청 지오코더를 사용해 대량으로 지오코딩하기', '13.8 포인트 데이터를 폴리곤 데이터로 피벗하기', '13.9 마치며', '[PART IV 진실하고 의미 있는 스토리 전달하기]', 'CHAPTER 14 거짓을 발견하고 편향 줄이기', '14.1 차트로 거짓말하는 방법', '14.2 지도로 거짓말하는 방법', '14.3 데이터 편향 인지하고 줄이기', '14.4 공간 편향 인지하고 줄이기', '14.5 마치며', 'CHAPTER 15 데이터 스토리 말하고 보여주기', '15.1 스토리보드에 내러티브 작성하기', '15.2 의미에 주의를 기울이세요', '15.3 출처와 불확실성 인정하기', '15.4 데이터 스토리 형식 결정하기', '15.5 마치며', 'APPENDIX 자주 발생하는 문제 해결법', 'A.1 도구 또는 플랫폼 문제', 'A.2 다른 브라우저 사용해보기', 'A.3 개발 도구로 진단하기', 'A.4 맥 또는 크롬북 문제', 'A.5 불량 데이터 체크하기', 'A.6 흔히 발생하는 iframe 에러', 'A.7 깃허브에서 코드 수정하기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B9063949643', 'title': 'IT CookBook, TCP/IP 소켓 프로그래밍(2판)', 'price': '32,000', 'content': ['Chapter 01 네트워크와 소켓 프로그래밍', '01 TCP/IP 프로토콜 개요', '02 소켓의 개념', '03 소켓의 특징과 구조', '04 소켓 프로그램 맛보기', '실습 1-1 윈도우 소켓 프로그램 작성과 테스트', '실습 1-2 리눅스 소켓 프로그램 작성과 테스트', '요약', '연습문제', 'Chapter 02 소켓 시작하기', '01 오류 처리', '02 소켓 초기화와 종료', '03 소켓 생성과 닫기', '실습 2-1 윈속 초기화와 종료하기', '실습 2-2 소켓 생성과 닫기', '요약', '연습문제', 'Chapter 03 소켓 주소 구조체 다루기', '01 소켓 주소 구조체', '02 바이트 정렬 함수', '03 IP 주소 변환 함수', '04 DNS와 이름 변환 함수', '실습 3-1 바이트 정렬 함수 연습', '실습 3-2 IP 주소 변환 함수 연습', '실습 3-3 이름 변환 함수 연습', '요약', '연습문제', 'Chapter 04 TCP 서버-클라이언트', '01 TCP 서버-클라이언트 구조', '02 TCP 서버-클라이언트 분석', '03 TCP 서버-클라이언트(IPv6)', '실습 4-1 TCP 서버-클라이언트 작성', '실습 4-2 TCP 서버-클라이언트 테스트', '실습 4-3 TCP 서버-클라이언트(IPv6) 작성과 테스트', '요약', '연습문제', 'Chapter 05 데이터 전송하기', '01 응용 프로그램 프로토콜과 데이터 전송', '02 다양한 데이터 전송 방식', '실습 5-1 고정 길이 데이터 전송 연습', '실습 5-2 가변 길이 데이터 전송 연습', '실습 5-3 고정 길이 + 가변 길이 데이터 전송 연습', '실습 5-4 데이터 전송 후 종료 연습', '요약', '연습문제', 'Chapter 06 멀티스레드: 윈도우', '01 스레드 기초', '02 스레드 API', '03 멀티스레드 TCP 서버', '04 스레드 동기화', '실습 6-1 스레드 생성과 종료, 인수 전달 연습', '실습 6-2 스레드 우선순위 변경 연습', '실습 6-3 스레드 실행 제어와 종료 기다리기 연습', '실습 6-4 멀티스레드 TCP 서버 작성과 테스트', '실습 6-5 임계 영역 연습', '실습 6-6 이벤트 연습', '요약', '연습문제', 'Chapter 07 멀티스레드: 리눅스', '01 스레드 API', '02 멀티스레드 TCP 서버', '03 스레드 동기화', '실습 7-1 스레드 생성과 종료, 인수 전달 연습', '실습 7-2 스레드 우선순위 변경 연습', '실습 7-3 스레드 종료 기다리기 연습', '실습 7-4 멀티스레드 TCP 서버 작성과 테스트', '실습 7-5 뮤텍스 연습', '실습 7-6 조건 변수 연습', '요약', '연습문제', 'Chapter 08 UDP 서버-클라이언트', '01 UDP 서버-클라이언트 구조', '02 UDP 서버-클라이언트 분석', '03 UDP 서버-클라이언트(IPv6)', '04 브로드캐스팅', '실습 8-1 UDP 서버-클라이언트 작성과 테스트', '실습 8-2 UDP 서버-클라이언트(IPv6) 작성과 테스트', '실습 8-3 UDP 브로드캐스팅 예제 작성과 테스트', '요약', '연습문제', 'Chapter 09 소켓 옵션', '01 소켓 옵션의 종류와 관련 함수', '02 SOL_SOCKET 레벨 옵션', '03 IPPROTO_IP, IPPROTO_IPV6 레벨 옵션', '04 IPPROTO_TCP 레벨 옵션', '실습 9-1 SO_REUSEADDR 옵션 테스트', '실습 9-2 멀티캐스팅(IPv4) 예제 작성과 테스트', '실습 9-3 멀티캐스팅(IPv6) 예제 작성과 테스트', '요약', '연습문제', 'Chapter 10 GUI 소켓 응용 프로그램: 윈도우', '01 GUI 응용 프로그램', '02 GUI 소켓 응용 프로그램', '03 대화상자 기반 응용 프로그램', '04 대화상자 기반 소켓 응용 프로그램', '실습 10-1 GUI 응용 프로그램 작성과 테스트', '실습 10-2 GUI 소켓 응용 프로그램 작성과 테스트', '실습 10-3 대화상자 기반 응용 프로그램 작성과 테스트', '실습 10-4 대화상자 기반 소켓 응용 프로그램 작성과 테스트', '요약', '연습문제', 'Chapter 11 소켓 입출력 모델: 윈도우', '01 소켓 입출력 모델 개요', '02 Select 모델', '03 WSAAsyncSelect 모델', '04 Completion Port 모델', '05 소켓 입출력 모델 비교', '실습 11-1 넌블로킹 소켓 연습', '실습 11-2 Select 모델 TCP 서버 작성과 테스트', '실습 11-3 WSAAsyncSelect 모델 TCP 서버 작성과 테스트', '실습 11-4 Completion Port 모델 TCP 서버 작성과 테스트', '요약', '연습문제', 'Chapter 12 소켓 입출력 모델: 리눅스', '01 소켓 입출력 모델 개요', '02 Select 모델', '03 Poll 모델', '04 EPoll 모델', '05 소켓 입출력 모델 비교', '실습 12-1 넌블로킹 소켓 연습', '실습 12-2 Select 모델 TCP 서버 작성과 테스트', '실습 12-3 Poll 모델 TCP 서버 작성과 테스트', '실습 12-4 EPoll 모델 TCP 서버 작성과 테스트', '요약', '연습문제', 'Chapter 13 직렬 통신과 블루투스 통신: 윈도우', '01 직렬 통신', '실습 13-1 직렬 통신 프로그램 작성과 테스트', '02 블루투스 통신', '실습 13-2 블루투스 장치 검색 프로그램 작성과 테스트', '실습 13-3 블루투스 통신 프로그램 작성과 테스트', '요약', '연습문제', 'Chapter 14 IPv4/IPv6 + TCP/UDP 지원 데이터 전송 프로그램', '01 프로젝트 개요', '02 응용 프로그램 작성', '실습 14-1 IPv4/IPv6 + TCP/UDP 지원 서버 작성', '실습 14-2 IPv4/IPv6 + TCP/UDP 지원 클라이언트 작성', '03 서버 코드 분석: 윈도우', '04 서버 코드 변환: 리눅스', '05 클라이언트 코드 분석', '06 추가 구현 사항']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B7400451696', 'title': 'IT CookBook, 쉽게 배우는 데이터 통신과 컴퓨터 네트워크(3판)', 'price': '30,000', 'content': ['Chapter 01 네트워크 기초', '01 용어의 정의', '02 구조적 모델', '03 주소의 표현', '요약', '연습문제', '현장의 목소리 01', 'Chapter 02 네트워크 개념', '01 프로토콜의 이해', '02 OSI 7계층 모델', '03 인터넷 모델', '요약', '연습문제', 'Chapter 03 네트워크 기술', '01 라우팅 기능', '02 네트워크의 분류', '03 인터네트워킹', '04 서비스 품질', '요약', '연습문제', 'Chapter 04 데이터 전송', '01 전송 방식', '02 오류 제어', '03 프레임 구조', '04 오류 검출 기법', '요약', '연습문제', '현장의 목소리 02', 'Chapter 05 MAC 계층', '01 IEEE 802 시리즈', '02 CSMA/CD', '03 토큰 버스', '04 토큰 링', '요약', '연습문제', 'Chapter 06 데이터 링크 계층', '01 프로토콜의 기초', '02 슬라이딩 윈도우 프로토콜', '03 HDLC 프로토콜', '요약', '연습문제', 'Chapter 07 IP 프로토콜', '01 네트워크 계층의 기능', '02 라우팅 프로토콜', '03 IP 프로토', '요약', '연습문제', '현장의 목소리 03', 'Chapter 08 네트워크 계층', '01 IPv6 프로토콜', '02 이동 IP 프로토콜', '03 제어용 프로토콜', '요약', '연습문제', 'Chapter 09 TCP 프로토콜', '01 전송 계층의 기능', '02 TCP의 헤더 구조', '03 TCP의 동작 원리', '요약', '연습문제', 'Chapter 10 전송 계층', '01 UDP 프로토콜', '02 RTP 프로토콜', '03 OSI TP 프로토콜', '요약', '연습문제', '현장의 목소리 04', 'Chapter 11 상위 계층', '01 상위 계층의 이해', '02 세션 계층', '03 표현 계층', '04 응용 계층', '요약', '연습문제', 'Chapter 12 네트워크 프로그래밍', '01 소켓의 주소 체계', '02 소켓 시스템 콜', '03 클라이언트ㆍ서버 프로그래밍', '요약', '연습문제', '현장의 목소리 05', 'Chapter 13 웹', '01 웹의 구조', '02 HTML의 기초', '03 HTTP 프로토콜', '04 CGI', '요약', '연습문제', 'Chapter 14 DNS', '01 주소의 변환', '02 네임 스페이스', '03 네임 서버와 해석기', '04 DNS 프로토콜', '요약', '연습문제', 'Chapter 15 전자 메일', '01 사용자 환경', '02 시스템 구조', '03 SMTP 프로토콜', '04 POP 서비스', '요약', '연습문제', '현장의 목소리 06', 'Chapter 16 파일 전송', '01 FTP 응용 프로그램', '02 FTP 프로토콜', '03 TFTP 프로토콜', '요약', '연습문제', 'Chapter 17 암호화와 네트워크 보안', '01 암호화의 이해', '02 암호화 시스템', '03 보안 프로토콜', '요약', '연습문제', '참고문헌', '찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B6129400746', 'title': 'IT CookBook, 우분투 리눅스(3판)', 'price': '34,000', 'content': ['PART 01 리눅스의 기본', 'Chapter 01 리눅스 설치와 기본 사용법', '00 개요', '01 리눅스 기초', '02 리눅스 실습 환경 구축', '03 리눅스 윈도 기본 사용법', '04 리눅스 명령 사용법', '연습문제', 'Chapter 02 디렉터리와 파일 사용법', '00 개요', '01 리눅스의 파일과 디렉터리', '02 디렉터리 관련 명령', '03 파일 관련 명령', '연습문제', 'Chapter 03 문서 편집', '00 개요', '01 리눅스의 문서 편집기', '02 vi 사용법', '03 vi 환경 설정', '연습문제', 'Chapter 04 셸 사용법', '00 개요', '01 셸의 기능과 종류', '02 셸 기본 사용법', '03 입출력 방향 변경', '04 배시셸 환경 설정', '05 앨리어스와 히스토리', '06 프롬프트 설정', '07 환경 설정 파일', '연습문제', 'Chapter 05 파일 접근 권한 관리', '00 개요', '01 파일 속성', '02 파일 접근 권한', '03 기호를 이용한 파일 접근 권한 변경', '04 숫자를 이용한 파일 접근 권한 변경', '05 기본 접근 권한 설정', '06 특수 접근 권한 설정', '연습문제', 'Chapter 06 프로세스 관리', '00 개요', '01 프로세스의 개념', '02 프로세스 관리 명령', '03 포그라운드ㆍ백그라운드 프로세스와 작업 제어', '04 작업 예약', '연습문제', 'PART 02 리눅스 시스템 관리', 'Chapter 07 파일 시스템과 디스크 관리', '00 개요', '01 리눅스 파일 시스템 종류', '02 리눅스 파일 시스템 구조', '03 파일 시스템 마운트', '04 디스크 추가 설치', '05 디스크 관리', '연습문제', 'Chapter 08 리눅스의 부팅과 종료', '00 개요', '01 리눅스 시스템의 부팅', '02 systemd 서비스', '03 리눅스 시스템의 종료', '04 데몬 프로세스', '05 부트 로더', '연습문제', 'Chapter 09 소프트웨어 관리', '00 개요', '01 우분투 패키지의 개요', '02 우분투 패키지 설치', '03 스냅 패키지 설치', '04 파일 아카이브와 압축', '05 소프트웨어 컴파일', '연습문제', 'Chapter 10 사용자 관리', '00 개요', '01 사용자 계정 관련 파일', '02 사용자 계정 관리 명령', '03 그룹 관리 명령', '04 사용자 정보 관리 명령', '05 디스크 사용량(쿼터) 설정', '연습문제', 'PART 03 리눅스 네트워크 서비스 관리', 'Chapter 11 네트워크 설정', '00 개요', '01 네트워크 기초', '02 네트워크 설정', '03 호스트 이름 설정', '04 네트워크 상태 확인', '연습문제', 'Chapter 12 원격 접속과 FTP', '00 개요', '01 텔넷과 SSH', '02 파일 송수신', '03 메일 송수신', '연습문제', 'Chapter 13 DB 서버와 웹 서버', '00 개요', '01 데이터베이스', '02 MariaDB 설치와 사용', '03 웹 서버 설치와 사용', '연습문제', 'Chapter 14 NFS와 삼바', '00 개요', '01 NFS 설치와 운영', '02 삼바 설치와 활용', '연습문제', 'PART 04 리눅스 보안 및 프로젝트', 'Chapter 15 리눅스 보안의 기초', '00 개요', '01 정보 보안의 기초', '02 시스템 로그', '03 방화벽 관리', '04 보안 관리 도구', '연습문제', 'Chapter 16 프로젝트', '01 프로젝트의 개요와 환경 구성', '02 프로젝트 시나리오', '연습문제', '찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B7738896383', 'title': '거시경제학(3판)', 'price': '36,000', 'content': ['제1편 거시경제학의 기초', '제1장 거시경제학의 주요 관심사', '제2장 거시경제의 측정 Ⅰ: 국민소득', '제3장 거시경제의 측정 Ⅱ: 인플레이션과 실업', '제4장 국민소득의 생산과 분배', '부록: 생산함수와 관계된 주요 거시경제변수', '제5장 지출 측면의 국민소득', '부록: 개방경제의 순환 과정', '제1편 요약', '제1편 연습문제', '제2편 국민소득 결정이론: 단순모형', '제6장 고전학파모형', '제7장 단순 케인즈모형', '제8장 실업: 고전학파 대 케인즈', '부록: 우리나라의 실업률과 경제성장률 추이 86', '제2편 요약', '제2편 연습문제', '제3편 화폐와 거시경제', '제9장 화폐와 금융시장', '제10장 화폐와 물가', '제11장 이자율: 고전학파 대 케인즈', '부록: 예상인플레이션과 물가 126', '제3편 요약', '제3편 연습문제', '제4편 거시경제의 수요 측면', '제12장 IS-LM 곡선의 도출', '제13장 IS-LM 모형과 재정·통화정책', '부록: 코로나 경제 위기에 대한 IS-LM 분석', '제14장 물가, 예상인플레이션과 IS-LM 모형', '부록: 수식으로 표현한 IS-LM 모형', '제4편 요약', '제4편 연습문제', '제5편 총수요·총공급모형', '제15장 단기와 장기', '제16장 총공급곡선의 도출 Ⅰ: 착오와 불완전정보', '제17장 총공급곡선의 도출Ⅱ: 임금과 가격의 경직성', '부록: 불완전경쟁과 총공급곡선', '제18장 기대형성과 총공급곡선', '제19장 총수요·총공급 충격과 경기변동', '제20장 필립스곡선', '부록: 우리나라의 필립스곡선과 오쿤의 법칙 248', '제5편 요약', '제5편 연습문제', '제6편 경제성장', '제21장 경제성장의 요인과 성장회계', '부록: 우리나라의 성장회계', '제22장 자본축적과 솔로우모형', '부록: 고령화와 경제성장률', '제23장 기술진보와 솔로우모형', '제24장 내생적 성장이론', '제6편 요약', '제6편 연습문제', '제7편 거시경제학의 미시경제적 기초', '제25장 소비이론 Ⅰ: 기본모형', '제26장 소비이론 Ⅱ: 다기간 선택', '제27장 소비이론 Ⅲ: 재정정책과 소비', '부록: 우리나라 소비 변동의 특성', '제28장 투자이론 Ⅰ: 기본모형', '부록: 자본의 한계효율과 투자의 한계효율', '제29장 투자이론 Ⅱ: 투자의 불안정성', '부록: 우리나라 설비투자 변동의 특성', '제30장 화폐의 공급', '제31장 화폐의 수요', '부록: 우리나라 화폐수요함수의 특성', '제7편 요약', '제7편 연습문제', '제8편 개방거시경제', '제32장 국제수지와 환율', '부록: 마샬-러너 조건의 도출', '제33장 구매력평가와 이자율평가', '부록: 국가위험도와 이자율평가', '제34장 개방거시경제모형: 수요 측면', '제35장 환율과 물가의 조정, 외환위기, 환율제도의 선택', '부록: 관리변동환율과 불태화 외환시장 개입', '제8편 요약', '제8편 연습문제', '제9편 경기변동과 안정화정책에 대한 논쟁', '제36장 새고전학파의 도전', '제37장 RBC 이론', '제38장 새케인즈학파의 주요 이론', '제39장 이자율 준칙과 IS-MP 모형', '제40장 안정화정책: 종합', '부록: 정부부채 비율의 계산', '제9편 요약', '제9편 연습문제', '부록 연습문제(선택형, 서술형) 해답 및 해설', '찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B4354575770', 'title': '생각하는 힘이 붙는 첫 숨은그림찾기', 'price': '6,300', 'content': []}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B1959656080', 'title': '실용적 접근 방식의 경영학원론(10판)', 'price': '39,000', 'content': ['PART 01 도입', 'CHAPTER 01 경영자', 'SECTION 01 경영의 의미', 'SECTION 02 경영의 네 가지 주요 기능', 'SECTION 03 경영의 수준과 분야', 'SECTION 04 경영자의 역할', 'SECTION 05 경영자에게 필요한 스킬', 'SECTION 06 경영자가 해결해야 할 일곱 가지 과제', 'SECTION 07 커리어 준비', 'SECTION 08 커리어 준비 실천', 'CHAPTER 02 경영 이론', 'SECTION 01 현대 경영 이론의 탄생 배경', 'SECTION 02 고전 이론', 'SECTION 03 행동주의 관점', 'SECTION 04 계량적 관점', 'SECTION 05 시스템 관점', 'SECTION 06 상황론적 관점', 'SECTION 07 최신 접근법', 'SECTION 08 커리어 준비 실천', 'PART 02 경영 환경', 'CHAPTER 03 경영 환경과 윤리적 책임', 'SECTION 01 비즈니스의 목적', 'SECTION 02 조직 내부의 이해관계자', 'SECTION 03 조직 외부의 이해관계자', 'SECTION 04 경영자에게 요구되는 윤리적 책임', 'SECTION 05 경영자에게 요구되는 사회적 책임', 'SECTION 06 기업 지배 구조', 'SECTION 07 커리어 준비 실천', 'CHAPTER 04 국제 경영', 'SECTION 01 세계화', 'SECTION 02 국제 경영과 글로벌 경영자', 'SECTION 03 기업의 해외 시장 진출 방식', 'SECTION 04 지역 경제의 협력과 경쟁', 'SECTION 05 문화적 차이 이해의 중요성', 'SECTION 06 커리어 준비 실천', 'PART 03 계획', 'CHAPTER 05 경영 계획', 'SECTION 01 계획과 전략', 'SECTION 02 계획의 기초', 'SECTION 03 목표와 계획', 'SECTION 04 목표의 일관성', 'SECTION 05 계획·통제 주기', 'SECTION 06 커리어 준비 실천', 'CHAPTER 06 전략 경영', 'SECTION 01 전략적 포지셔닝과 전략의 수준', 'SECTION 02 전략 경영 프로세스', 'SECTION 03 현상황 진단', 'SECTION 04 기업 수준 전략', 'SECTION 05 사업 수준 전략', 'SECTION 06 기능 수준 전략', 'SECTION 07 커리어 준비 실천', 'CHAPTER 07 개인과 집단 의사 결정', 'SECTION 01 합리적인 의사 결정과 비합리적인', 'SECTION 02 윤리적인 의사 결정', 'SECTION 03 증거 기반 의사 결정과 자료 분석', 'SECTION 04 인공 지능을 활용한 의사 결정', 'SECTION 05 의사 결정의 네 가지 스타일', 'SECTION 06 의사 결정의 열 가지 편향', 'SECTION 07 집단 의사 결정', 'SECTION 08 커리어 준비 실천', 'PART 04 조직', 'CHAPTER 08 조직 문화와 조직 구조', 'SECTION 01 전략에 맞추는 조직 문화, 조직 구조, HR 제도', 'SECTION 02 조직 문화', 'SECTION 03 조직 문화의 변화 과정', 'SECTION 04 조직 구조', 'SECTION 05 조직 구조의 유형', 'SECTION 06 커리어 준비 실천', 'CHAPTER 09 인적 자원 관리', 'SECTION 01 전략적 인적 자원 관리', 'SECTION 02 모집과 채용', 'SECTION 03 보상과 복리 후생', 'SECTION 04 학습과 개발', 'SECTION 05 성과 관리', 'SECTION 06 승진, 전출, 징계, 해고', 'SECTION 07 노사 관계', 'SECTION 08 커리어 준비 실천', 'CHAPTER 10 조직 변화와 혁신', 'SECTION 01 조직 변화', 'SECTION 02 조직 변화의 이론', 'SECTION 03 조직 개발', 'SECTION 04 조직 혁신', 'SECTION 05 조직 변화의 장애 요인', 'SECTION 06 커리어 준비 실천', 'PART 05 리드', 'CHAPTER 11 개인 차이와 행동', 'SECTION 01 성격과 개인 행동', 'SECTION 02 가치, 태도, 행동', 'SECTION 03 지각과 개인 행동', 'SECTION 04 직무 태도와 행동', 'SECTION 05 인력의 다양성', 'SECTION 06 스트레스와 개인 행동 이해', 'SECTION 07 커리어 준비 실천', 'CHAPTER 12 직원 동기 부여', 'SECTION 01 동기 부여', 'SECTION 02 동기 부여의 내용 이론', 'SECTION 03 동기 부여의 과정 이론', 'SECTION 04 동기 부여를 위한 직무 설계', 'SECTION 05 동기 부여를 위한 강화 이론', 'SECTION 06 동기 부여를 위한 보상', 'SECTION 07 커리어 준비 실천', 'CHAPTER 13 집단과 팀', 'SECTION 01 집단과 팀', 'SECTION 02 집단과 팀의 개발 과정', 'SECTION 03 효과적인 팀 구축', 'SECTION 04 갈등 관리', 'SECTION 05 커리어 준비 실천', 'CHAPTER 14 권력, 영향, 그리고 리더십', 'SECTION 01 권력과 영향', 'SECTION 02 리더십의 특성 이론', 'SECTION 03 리더십의 행동 이론', 'SECTION 04 리더십의 상황 이론', 'SECTION 05 거래적 리더십과 변혁적 리더십', 'SECTION 06 리더십의 최근 이론', 'SECTION 07 커리어 준비 실천', 'CHAPTER 15 의사소통', 'SECTION 01 의사소통의 의미와 과정', 'SECTION 02 의사소통의 경로', 'SECTION 03 의사소통의 장애물', 'SECTION 04 소셜 미디어 관리', 'SECTION 05 의사소통의 효과성', 'SECTION 06 커리어 준비 실천', 'PART 06 통제', 'CHAPTER 16 통제와 품질 경영', 'SECTION 01 통제', 'SECTION 02 통제 과정과 유형', 'SECTION 03 통제 방법', 'SECTION 04 전사적 품질 관리', 'SECTION 05 현대의 통제 방법', 'SECTION 06 커리어 준비 실천', 'SECTION 07 맺는 말: 미래의 성공과 행복을 위한 제언', 'Index', '부록', '- 학습 모듈 1', '- 학습 모듈 2', '※ 학습 모듈은 ‘https://hanbit.co.kr/src/4599’에서 내려받을 수 있습니다.']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B5171715268', 'title': '인피니티', 'price': '17,820', 'content': ['서문 | 과학이 허구를 넘어설 때', '들어가는 말 | 무한에 대하여', '우주의 무한 | 우주는 지금 몇 시일까', '양자의 무한 | 환영으로 이루어진 세계', '에필로그 | 진공의 숨결', '용어설명', '참고문헌']}

# %% [markdown]
# - python_crawler_final.ipynb실습

# %%
import time
import requests
import lxml.html
import re

# %%
def main():
    # 여러 페이지에서 크롤링을 위해 Session 사용
    session = requests.Session()  
    # scrape_list_page() 함수를 호출해서 제너레이터를 추출
    response = session.get('http://www.hanbit.co.kr/store/books/new_book_list.html')
    urls = scrape_list_page(response)
    for url in urls:
        time.sleep(1) # 1초간 대기
        response = session.get(url)  # Session을 사용해 상세 페이지를 추출
        ebook = scrape_detail_page(response)  # 상세 페이지에서 상세 정보를 추출
        print(ebook)  # 상세 정보 출력

# %%
def scrape_list_page(response):
    root = lxml.html.fromstring(response.content)
    root.make_links_absolute(response.url)
    for a in root.cssselect('.view_box .book_tit a'):
        url = a.get('href')
        yield url

# %%
def scrape_detail_page(response):
    """
    상세 페이지의 Response에서 책 정보를 dict로 추출
    """
    root = lxml.html.fromstring(response.content)
    ebook = {
        'url': response.url,
        'title': root.cssselect('.store_product_info_box h3')[0].text_content(),
        'price': root.cssselect('.pbr strong')[0].text_content(),
        'content': [normalize_spaces(p.text_content())
            for p in root.cssselect('#tabs_3 .hanbit_edit_view p')
            if normalize_spaces(p.text_content()) != '']
    }
    return ebook

# %%
def normalize_spaces(s):
    """
    연결된 공백을 하나의 공백으로 변경
    """
    return re.sub(r'\s+', ' ', s).strip()

# %%
if __name__ == '__main__':
    main()
# Out:
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B3178834938', 'title': '받침 없는 한글 동화 : 4권 세트', 'price': '49,680', 'content': ['<1편>', '이렇게 읽어요', '1. 무시무시 마녀가 이사 와!', '2. 아기 고래 뿌우의 노래', '<2편>', '이렇게 읽어요', '1. 도, 도, 도깨비다!', '2. 느티나무 아파트', '<3편>', '이렇게 읽어요', '1. 바쁘다 바빠 너구리 바빠', '2. 꼬마 지우개 마구마구', '<4편>', '이렇게 읽어요', '1. 도깨비 파자마 파티', '2. 꼬마 두루미 뚜루']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B6084607806', 'title': '받침 없는 한글 동화 : 도, 도, 도깨비다!', 'price': '12,420', 'content': ['이렇게 읽어요', '1. 도, 도, 도깨비다!', '2. 느티나무 아파트']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B8948111854', 'title': '받침 없는 한글 동화 : 도깨비 파자마 파티', 'price': '12,420', 'content': ['이렇게 읽어요', '1. 도깨비 파자마 파티', '2. 꼬마 두루미 뚜루']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B8661740335', 'title': '받침 없는 한글 동화 : 무시무시 마녀가 이사 와!', 'price': '12,420', 'content': ['이렇게 읽어요', '1. 무시무시 마녀가 이사 와!', '2. 아기 고래 뿌우의 노래']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B1382037871', 'title': '받침 없는 한글 동화 : 바쁘다 바빠 너구리 바빠', 'price': '12,420', 'content': ['이렇게 읽어요', '1. 바쁘다 바빠 너구리 바빠', '2. 꼬마 지우개 마구마구']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B2847674054', 'title': '리얼 몽골 [2022~2023 최신판]', 'price': '16,200', 'content': ['작가의 말', '몽골 지역 구분', '구글 지도 활용', 'PART 01 한눈에 보는 몽골', '한눈에 보는 몽골', '숫자로 보는 몽골', '몽골 기본 정보', '몽골 문화와 에티켓', '몽골 연중 날씨', '몽골 4색 테마 여행', '몽골 여행 키워드 10', '몽골 필수 여행지 10', '몽골 문화 & 역사', '추천 여행 코스', '완전 정복 2주 코스', '고비 사막 1주 코스', '홉스골 10일 코스', '울란바토르 알짜배기 코스', '테렐지 1박 2일 코스', 'PART 02 몽골을 가장 멋지게 여행하는 방법', '테마 여행', '액티비티', '몽골 동물', '전통 공연', '종교 문화', '불교 사원', '박물관 & 미술관', '나담 축제', '차강사르', '미식 여행', '전통 음식', '몽골리안 바비큐 & 핫팟', '럭셔리 레스토랑', '라운지 바 & 클럽', '몽골 맥주 & 보드카', '몽골 베이커리', '몽골 전통 음료', '쇼핑 여행', '여행 기념품점', '추천 기념품', '마트 & 드럭스토어 아이템', '캐시미어 아웃렛', '백화점 & 쇼핑몰', '전통시장 & 대형마트', 'PART 03 쉽고 즐거운 여행 준비', '준비 편', '몽골 여행 계획하기', '여행 준비 캘린더', '투어 차량 선택 노하우', '여행사 선정 방법', '은하수 촬영 꿀팁', '몽골 여행 준비물', '웹사이트 & 애플리케이션', '실전 편', '몽골 입국 절차', '칭기즈칸 국제공항', '울란바토르 시티투어 버스', '몽골 종단 철도', '환전 및 유심 카드', '[REAL GUIDE] 몽골 화폐', '추천 장보기 리스트', '몽골 여행 생활 가이드', '몽골 숙소의 모든 것', 'PART 04 진짜 몽골을 만나는 시간', '구역별로 만나는 몽골', '몽골 여행의 시작 울란바토르', '울란바토르 대중교통', 'SECTION A 울란바토르 중심부', '상세 지도', '추천 스폿', 'SECTION B 울란바토르 서남부', '상세 지도', '추천 스폿', '[REAL GUIDE]', '숨은 한국 찾기', 'SECTION C 울란바토르 동부', '상세 지도', '추천 스폿', '초원 위 힐링 여행지 테렐지 국립공원', '상세 지도', '가는 방법', '추천 스폿', '[REAL GUIDE]', '13세기 마을 테마 공원', '전통가옥 게르', '몽골 여행의 하이라이트 고비 사막', '상세 지도', '추천 스폿', '[REAL GUIDE]', '낙타 체험 & 모래 썰매', '몽골의 푸른 보석 홉스골', '상세 지도', '추천 스폿', '[REAL GUIDE]', '쳉헤르의 5대 온천', '홉스골 호수', '승마·ATV·수중 액티비티 체험', 'INDEX']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B4162156367', 'title': '오늘도 시작하지 못하는 당신을 위해', 'price': '14,850', 'content': ['프롤로그', '1장 완벽주의자의 탄생', '당신은 완벽주의자인가요?', ': 저는 완벽주의자가 아니에요', ': 이론 속 완벽주의자 유형', '우리는 어쩌면 대부분 완벽주의자', ': 생활 속 완벽주의자 유형', '-회피형 완벽주의자', '-감독형 완벽주의자', '-자책형 완벽주의자', '-안정형 완벽주의자', '2장 완벽주의, 스스로 만든 정신적 감옥', '우리는 모두 완벽을 강요당한다', ': 성과주의 문화가 낳은 괴물', ': 1등이 되면 고민은 끝이라는 착각', ': 온라인 세상으로 맞이한 또 다른 완벽주의', ': 불안과 우울, 그 너머에 있는 마음', '완벽주의자가 빠지기 쉬운 네 가지 함정', ': 지금 당장 버려야 할 완벽주의 생각 습관', '-당위성(should)의 오류', '-흑백논리의 오류', '-과잉(지나친) 일반화', '-재앙화(파국화) 사고', '3장 완벽주의 성향이 높은 편입니다', '완벽주의가 삶에 지장을 주려 할 때', ': 완벽주의 성향을 파악하는 척도', ': 완벽주의자의 성격', ': 나는 이만하면 괜찮은 완벽주의자?', '완벽주의 늪에 빠진 사람들', ': 양육 환경으로 완벽주의가 대물림된다', ': 평가에 민감한 사람들', ': 타인의 인정이 삶의 목표가 될 수는 없다', '완벽하려는 강박이 불러오는 이상 증세', ': 완벽주의자가 감정을 대하는 방식', ': 완벽주의자를 누르고 있는 감정들', '-죄책감과 수치심', '-걱정과 불안', '-우울과 슬픔', ': 완벽주의자가 낳은 질병들', '-강박장애', '-섭식장애', '-번아웃', '-무대 공포증', '4장 완벽주의의 균형을 찾아서', '완벽주의라는 허상', ': 낮은 완벽주의, 높은 성취감', ': 완벽주의자에게 진짜 필요한 능력', '서로가 서로를 도울 수 있다', ': 완벽주의자가 쉽게 우울해지는 이유', ': 완벽주의자를 둘러싼 관계 재조명', '-부모와 자녀', '-부부 혹은 연인', '-리더와 조직원', '5장 완벽주의 성향이 높은 편입니다', '1주차_인정하라', ': 성과를 가로막는 진짜 장애물을 파악하라', ': 인정하는 연습, 나는 완벽주의자입니다', '2주차_기준을 바꾸라', ': 완벽주의자들의 비현실적인 기준', ': 기준을 바꾸는 연습', '3주차_두려움의 뿌리를 찾아라', ': 부정적인 감정 들여다보기', ': 혼자서 자동적 사고를 찾아보고 싶을 때', '4주차_실수에 대한 두려움을 버리고 계속 시도하기', ': 실수를 두려워하지 않는 사람은 없다', ': 실수를 기회로 바꾸는 방법', '5주차_완벽하지 않아서 행복한 사람들', ': 완벽주의를 조절하는 현실적인 기법', ': 내 안의 안정형 완벽주의를 키우자', '6장 완벽을 포기하고 완벽에 가까워진 사람들', '행복한 똑똑이가 되는 진짜 비결', ': 진짜 필요한 능력, 자기 효능감', ': 타인이 아닌 자신을 위한 노력', '두 마리 토끼를 모두 잡으려면', ': 역할 과부하에 시달리는 엄마들', ': 버거운 말을 거절하는 연습', '유니콘 기업의 건강한 조직 문화', ': 조직이 개인 퍼포먼스를 돕는 이유', ': 완벽하지 않은 조직문화의 가치', '운동선수도 피할 수 없는 완벽주의', ': 운동의 흐름을 방해하는 큰 위기, 입스', ': 심리적 불안이 일으킨 신체적 증상', ': 맹목적인 경쟁심에 사로잡히지 않으려면', '에필로그', '주', '부록: 완벽주의 극복 5주 프로그램 워크북']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B5156679966', 'title': 'IT CookBook, 원리로 이해하는 전력전자공학(2판)', 'price': '30,000', 'content': ['CHAPTER 01 전력전자공학의 기초', '1.1 개요', '1.2 기초 회로이론', '연습문제', 'CHAPTER 02 전력용 반도체 스위치', '2.1 개요', '2.2 다이오드', '2.3 전력용 트랜지스터', '2.4 사이리스터', '2.5 MOSFET', '2.6 IGBT', '2.7 와이드 밴드 갭 소자', '2.8 전력용 반도체 스위치 비교', '2.9 추가 부품', '연습문제', 'CHAPTER 03 정류기와 AC-AC 컨버터', '3.1 개요', '3.2 단상 반파 정류기', '3.3 단상 전파 정류기', '3.4 3상 반파 정류기', '3.5 3상 전파 정류기', '3.6 AC-AC 컨버터', '3.7 전원 측 인덕턴스의 영향', '연습문제', 'CHAPTER 04 비절연형 DC-DC 컨버터', '4.1 개요', '4.2 강압형 컨버터', '4.3 승압형 컨버터', '4.4 승강압형 컨버터', '4.5 비절연형 DC-DC 컨버터의 설계', '연습문제', 'CHAPTER 05 절연형 DC-DC 컨버터', '5.1 개요', '5.2 플라이백 컨버터 5.2', '5.3 포워드 컨버터 5.3', '5.4 푸시풀 컨버터', '5.5 하프 브리지 컨버터', '5.6 풀 브리지 컨버터', '5.7 역률 개선 회로', '연습문제', 'CHAPTER 06 인버터', '6.1 개요', '6.2 단상 하프 브리지 인버터', '6.3 단상 풀 브리지 인버터', '6.4 3상 전압원 인버터', '6.5 3상 전류원 인버터', '연습문제', 'CHAPTER 07 공진형 컨버터', '7.1 개요', '7.2 준 공진형 컨버터', '7.3 부하 공진형 컨버터', '7.4 위상천이 풀 브리지 컨버터', '연습문제', 'CHAPTER 08 고전압 대용량 전력변환', '8.1 개요', '8.2 다이오드 클램프 멀티레벨 인버터', '8.3 캐스케이디드 H-브리지 인버터', '8.4 모듈러 멀티레벨 컨버터', '8.5 다중 펄스 다이오드 정류기', '연습문제', 'CHAPTER 09 신재생에너지', '9.1 개요', '9.2 풍력에너지 시스템', '9.3 태양광에너지 시스템', '9.4 연료전지 시스템', '9.5 에너지 저장 시스템', '연습문제', 'CHAPTER 10 전력전자 응용', '10.1 개요', '10.2 유연 송전시스템(FACTS)', '10.3 마이크로그리드와 직류 송배전 기술', '10.4 반도체 변압기', '10.5 전기추진 응용', '10.6 핵융합 발전', '10.7 가전 응용', '연습문제']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B6189263297', 'title': '트러스트', 'price': '16,920', 'content': ['감사의 말 | 이 책에서 다룰 내용', 'Chapter 1. 신뢰의 역사', '생물학 | 선물 | 종교 | 중세의 시장과 국제무역 | 법률', 'Chapter 2. 전문기관에 대한 신뢰', '정치인 | 미디어 | 의학에 대한 신뢰 | 과학 | 기후변화', 'Chapter 3. 서로 신뢰하기', '낯선 사람에 대한 신뢰 | 자신에 대한 신뢰 | 사과와 비난 | 정체성, 존엄성, 프라이버시', 'Chapter 4. 신뢰의 경제학', '신뢰에 대한 경제학 서적을 읽는 이유 | 내가 신뢰에 대한 경제학 책을 쓴 이유 | 신뢰에 대한 경제학자의 생각 | 경제학적 신뢰이론 | 인과관계와 실증경제학자의 방법론', 'Chapter 5. 현대경제와 신뢰', '화폐 | 투자와 금융 | 계약 | 직장 | 브랜드 | 시장경제와 신뢰의 미래: 공유 경제와 블록체인', 'Chapter 6. 결론', '주 | 찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B4813114979', 'title': '구글 앱스 스크립트 완벽 가이드', 'price': '36,000', 'content': ['Chapter 1 구글 앱스 스크립트 기본 지식', '1.1 구글 앱스 스크립트', '1.2 구글 앱스와 구글 워크스페이스', '1.3 GAS로 조작할 수 있는 애플리케이션', '1.4 GAS 학습 시 주의할 점', 'Chapter 2 스크립트 편집기와 대시보드', '2.1 헬로! GAS', '2.2 프로젝트와 스크립트', '2.3 스크립트 편집기의 편집 기능', '2.4 로그와 디버그', '2.5 권한과 허가', '2.6 지원 메뉴와 레퍼런스', 'Chapter 3 기본 문법', '3.1 자바스크립트 기초', '3.2 변수와 상수', '3.3 데이터 타입', '3.4 배열', '3.5 객체', '3.6 산술 연산자와 대입 연산자', 'Chapter 4 제어문', '4.1 if문을 이용한 조건 분기', '4.2 조건식, 비교 연산자, 논리 연산자', '4.3 switch문을 이용한 다중 분기', '4.4 while문을 이용한 반복', '4.5 for문을 이용한 반복', '4.6 for...of문을 이용한 반복', '4.7 for...in문을 이용한 반복', '4.8 반복 처리 중단과 건너뛰기', '4.9 try...catch문과 예외 처리', 'Chapter 5 함수', '5.1 함수', '5.2 함수 리터럴', '5.3 스코프', 'Chapter 6 클래스와 객체', '6.1 객체, 속성, 메서드', '6.2 클래스와 인스턴스화', '6.3 메서드와 프로토타입', '6.4 정적 멤버', 'Chapter 7 자바스크립트의 내장 객체', '7.1 내장 객체', '7.2 수치 다루기 - Number 객체', '7.3 문자열 다루기 - String 객체', '7.4 배열 다루기 - Array 객체', '7.5 함수 다루기 - Function 객체', '7.6 날짜와 시간 다루기 - Date 객체', '7.7 정규 표현 다루기 - RegExp 객체', '7.8 예외 정보 얻기 - Error 객체', '7.9 수학 연산 실행하기 - Math 객체', '7.10 JSON 데이터 다루기 - JSON 객체', '7.11 객체 다루기 - Object 객체', '7.12 글로벌 함수', 'Chapter 8 스프레드시트', '8.1 Spreadsheet 서비스', '8.2 SpreadsheetApp 클래스', '8.3 스프레드시트 조작하기 - Spreadsheet 클래스', '8.4 시트 조작하기 - Sheet 클래스', '8.5 셀 범위 조작하기 - Range 클래스', '8.6 배열을 사용한 데이터 처리', '8.7 커스텀 함수', 'Chapter 9 지메일', '9.1 Gmail 서비스', '9.2 GmailApp 클래스', '9.3 스레드 얻기', '9.4 스레드 다루기 - GmailThread 클래스', '9.5 메시지 얻기', '9.6 메시지 다루기 - GmailMessage 클래스', 'Chapter 10 드라이브', '10.1 Drive 서비스', '10.2 DriveApp 클래스', '10.3 폴더 조작하기 - Folder 클래스', '10.4 파일 조작하기 - File 클래스', '10.5 폴더와 파일 컬렉션 조작하기', '10.6 폴더와 파일 공유 및 권한 조작하기', 'Chapter 11 캘린더', '11.1 Calendar 서비스', '11.2 CalendarApp 클래스', '11.3 캘린더 조작하기 - Calendar 클래스', '11.4 이벤트 조작하기 - CalendarEvent 클래스', 'Chapter 12 문서', '12.1 Document 서비스', '12.2 DocumentApp 클래스', '12.3 문서 조작하기 - Document 클래스', '12.4 섹션 조작하기', '12.5 단락 및 리스트 아이템 조작하기', '12.6 텍스트 객체 조작하기', '12.7 문자열 수정과 서식 설정', '12.8 문자열 찾기와 바꾸기', 'Chapter 13 프레젠테이션', '13.1 Slides 서비스', '13.2 SlidesApp 클래스', '13.3 프레젠테이션 조작하기 - Presentation 클래스', '13.4 프레젠테이션 조작하기 - Slide 클래스', '13.5 페이지 요소 조작하기', '13.6 텍스트 범위와 문자열 조작하기', 'Chapter 14 설문지', '14.1 Forms 서비스', '14.2 FormApp 클래스', '14.3 설문지 조작하기 - Form 클래스', '14.4 아이템 조작하기', 'Chapter 15 번역', '15.1 Language 서비스와 LanguageApp 클래스', 'Chapter 16 Base 서비스', '16.1 Base 서비스', '16.2 로그', '16.3 세션과 사용자', 'Chapter 17 사용자 인터페이스', '17.1 UI 조작과 UI 클래스', '17.2 다이얼로그', '17.3 메뉴', '17.4 스프레드시트 UI 확장하기', 'Chapter 18 파일과 데이터 조작', '18.1 Blob 객체', '18.2 첨부 파일 조작하기', 'Chapter 19 Utilities 서비스', '19.1 Utilities 서비스', '19.2 ZIP 파일과 CSV 파일', '19.3 날짜와 시간을 문자열로 바꾸기', 'Chapter 20 Properties 서비스', '20.1 속성 저장소', '20.2 Properties 서비스와 PropertiesService 클래스', '20.3 속성 저장소 읽고 쓰기 - Properties 클래스', 'Chapter 21 이벤트와 트리거', '21.1 심플 트리거', '21.2 인스톨러블 트리거', '21.3 이벤트 객체', '21.4 Script 서비스', 'Chapter 22 외부 서비스 접속', '22.1 Url Fetch 서비스', '22.2 HTTP 리퀘스트와 HTTP 리스폰스', '22.3 HTML, JSON에서 데이터 추출하기', 'Chapter 23 라이브러리', '23.1 라이브러리 이용하기', '23.2 라이브러리 만들기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B8806843023', 'title': '리얼 싱가포르 [2022~2023 최신판]', 'price': '16,200', 'content': ['작가의 말', '이 책의 사용법', 'PART 01 미리 보는 싱가포르', '한눈에 보는 싱가포르', '숫자로 보는 싱가포르', '싱가포르 여행 기본 정보', '싱가포르 명절 & 축제', '싱가포르 여행의 매력', '싱가포르 여행 버킷 리스트', '이건 꼭 먹자! 싱가포르 음식', '이건 꼭 사자! 싱가포르 아이템', '키워드로 읽는 싱가포르 역사', '알아두면 유용한 싱가포르 문화', '[REAL GUIDE]', '싱가포르 대중교통 이용하기', '파인다이닝 즐기기', '한정판 야경의 매력, 아이라이트 싱가포르', '센토사를 오가는 교통수단', '유니버설 스튜디오 싱가포르 예습하기', '싱가포르 4대 동물원 총정리', '여행의 마지막을 알뜰하게! GST 환급 받기', '공항 속 복합 쇼핑몰 주얼 창이 싱가포르', 'PART 02 싱가포르를 가장 멋지게 여행하는 방법', 'THEME', '레이저 쇼', '사원', '박물관', '전통 건축물', '현대 건축물', '시티 정글', '도서관 & 서점', '센토사의 명물', '루프톱 바', 'FOOD', '스타 셰프 레스토랑', '파인다이닝', '브런치 카페', '애프터눈 티', '호커 센터 & 푸드코트', '콘셉트 레스토랑', '로컬 맛집', '인스타그래머블 카페', '커피 맛집', '중국 음식', '싱가포르 베스트 바', 'SHOPPING', '오차드 로드 대표 쇼핑몰', '기념품 쇼핑', '개성 만점 편집숍', '로컬 디자이너 브랜드', '현지 마트', 'REAL COURSE GUIDE', '단기 집중 2박 3일 코스', '정석대로 핵심만 쏙쏙 3박 4일 코스', '느긋하게 즐기는 4박 5일 코스', '3박 4일 친구끼리 여행', '4박 5일 아이와 함께하는 가족 여행', '3박 4일 로맨틱 커플 여행', '3박 4일 식도락 여행', 'PART 03 진짜 싱가포르를 만나는 시간', 'AREA 1 올드 시티', '상세 지도', '추천 스폿', 'AREA 2 마리나 베이', '상세 지도', '추천 스폿', 'AREA 3 리버사이드', '상세 지도', '추천 스폿', 'AREA 4 오차드 로드', '상세 지도', '추천 스폿', 'AREA 5 차이나타운 & CBD', '상세 지도', '추천 스폿', 'AREA 6 부기스', '상세 지도', '추천 스폿', 'AREA 7 리틀 인디아', '상세 지도', '추천 스폿', 'AREA 8 센토사 & 하버프런트', '상세 지도', '추천 스폿', 'PART 04 개성 강한 주변 지역 여행', 'PLUS AREA 1 뎀시 힐', '지도와 추천 코스', '추천 스폿', 'PLUS AREA 2티옹바루', '지도와 추천 코스', '추천 스폿', 'PLUS AREA 3 카통', '지도와 추천 코스', '추천 스폿', 'PLUS AREA 4 홀랜드 빌리지', '지도와 추천 코스', '추천 스폿', 'PART 05 쉽고 즐거운 여행 준비', 'GUIDE 01 여행 준비 & 출입국', 'GUIDE 02 숙소']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B2859439220', 'title': '원소 이야기', 'price': '15,300', 'content': ['머리말: 현실을 요리하는 법', '1장 원소 사냥에 뛰어든 천재들', '2장 쪼개지지 않는 근원', '3장 원자 모형의 진화', '4장 원자는 어디에서 올까?', '5장 주기율표의 서막이 열리다', '6장 양자역학으로 해결된 주기율표', '7장 불안하면 터진다', '8장 연금술사의 꿈이 이루어지다', '9장 금속원소와 전기', '10장 산, 비금속원소, 빛', '11장 생명을 구성하는 모든 것이 주기율표에 있다', '12장 세상을 바꾼 원소들', '부록', '감사의 말', '주']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B1996635146', 'title': '핸즈온 데이터 시각화', 'price': '34,200', 'content': ['CHAPTER 0 서문', '0.1 왜 데이터 시각화인가', '0.2 무엇을 믿을 수 있을까요', '0.3 더 설득력 있는 그림', '0.4 진실의 여러 가지 그림자', '0.5 책의 구성', '0.6 마치며', '[PART I 기본 기술]', 'CHAPTER 1 스토리를 위한 도구 선택하기', '1.1 데이터 스토리 스케치하기', '1.2 도구를 선택할 때 고려해야 할 10가지 요소', '1.3 추천 도구', '1.4 패스워드 관리자 사용', '1.5 마치며', 'CHAPTER 2 스프레드시트 스킬 강화하기', '2.1 스프레드시트 도구 선택', '2.2 CSV 또는 ODS 형식으로 다운로드하기', '2.3 구글 시트 복사본 만들기', '2.4 구글 시트 공유하기', '2.5 구글 시트 업로드하고 변환하기', '2.6 구글 시트에서 주소 지오코딩하기', '2.7 구글 설문지로 데이터 수집하기', '2.8 데이터 정렬 및 필터', '2.9 수식을 사용해 계산하기', '2.10 피벗 테이블을 사용해 데이터 요약하기', '2.11 VLOOKUP을 사용해 열 매칭하기', '2.12 스프레드시트와 관계형 데이터베이스', '2.13 마치며', 'CHAPTER 3 데이터를 찾고 질문하기', '3.1 검색을 위한 질문 가이드', '3.2 공공 데이터와 개인 데이터', '3.3 민감한 데이터를 가리거나 집계하기', '3.4 오픈 데이터 저장소', '3.5 데이터 출처 남기기', '3.6 불량 데이터 인식하기', '3.7 데이터에 대해 질문하기', '3.8 마치며', 'CHAPTER 4 지저분한 데이터 정리하기', '4.1 구글 시트 스마트 클린업', '4.2 찾기 및 바꾸기', '4.3 행과 열 바꾸기', '4.4 데이터를 서로 다른 열로 나누기', '4.5 데이터를 한 열에 합치기', '4.6 타불라를 사용해 PDF에서 테이블 추출하기', '4.7 오픈리파인으로 데이터 정리하기', '4.8 마치며', 'CHAPTER 5 의미 있는 비교하기', '5.1 비교를 정확히 기술하기', '5.2 데이터 정규화하기', '5.3 편향된 비교 주의하기', '5.4 마치며', '[PART II 시각화 구축]', 'CHAPTER 6 차트 만들기', '6.1 차트 디자인 원칙', '6.2 구글 시트 차트', '6.3 막대 차트와 열 차트', '6.4 히스토그램', '6.5 원형 차트, 선 차트, 영역 차트', '6.6 데이터래퍼 차트', '6.7 주석이 달린 차트', '6.8 범위 차트', '6.9 분산형 차트와 버블 차트', '6.10 태블로 퍼블릭 차트', '6.11 태블로 퍼블릭으로 만드는 분산형 차트', '6.12 필터링된 선 차트', '6.13 마치며', 'CHAPTER 7 데이터를 지도로 시각화하기', '7.1 지도 디자인 원칙', '7.2 코로플레스 색상과 간격 디자인', '7.3 코로플레스 지도 데이터 정규화하기', '7.4 구글 내 지도로 만드는 포인트 지도', '7.5 데이터래퍼로 만드는 심벌 포인트 지도', '7.6 데이터래퍼로 만드는 코로플레스 지도', '7.7 태블로 퍼블릭으로 만드는 코로플레스 지도', '7.8 소크라타 오픈 데이터로 만드는 실시간 지도', '7.9 마치며', 'CHAPTER 8 테이블을 활용한 시각화', '8.1 테이블 디자인 원칙', '8.2 스파크라인으로 만드는 데이터래퍼 테이블', '8.3 기타 테이블 생성 도구', '8.4 마치며', 'CHAPTER 9 웹에 임베딩하기', '9.1 정적 이미지와 대화형 iframe', '9.2 임베드 코드 또는 iframe 태그 가져오기', '9.3 코드 또는 iframe을 웹사이트에 붙여넣기', '9.4 마치며', '[PART III 코드 템플릿과 고급 도구]', 'CHAPTER 10 깃허브로 코드 수정하고 호스트하기', '10.1 간단한 리플릿 맵 템플릿 복사, 수정, 호스팅하기', '10.2 깃허브 페이지 링크를 iframe으로 변환하기', '10.3 깃허브에 새로운 레포 만들고 파일 업로드하기', '10.4 깃허브 데스크톱과 아톰 텍스트 편집기를 사용해 효율적인 코딩하기', '10.5 마치며', 'CHAPTER 11 Chart.js와 하이차트 템플릿', '11.1 Chart.js로 만드는 막대 또는 열 차트', '11.2 Chart.js로 만드는 오류 바', '11.3 Chart.js로 만드는 선 차트', '11.4 하이차트로 만드는 주석이 달린 선 차트', '11.5 Chart.js로 만드는 분산형 차트', '11.6 Chart.js로 만드는 버블 차트', '11.7 마치며', 'CHAPTER 12 리플릿 맵 템플릿', '12.1 구글 시트로 만드는 리플릿 맵', '12.2 구글 시트로 만드는 리플릿 스토리맵', '12.3 구글 시트 API 키 가져오기', '12.4 CSV 데이터로 만드는 리플릿 맵', '12.5 CSV 데이터로 만드는 리플릿 히트맵 포인트', '12.6 검색 가능한 리플릿 포인트 지도', '12.7 오픈 데이터 API로 만드는 리플릿 맵', '12.8 마치며', 'CHAPTER 13 지도 데이터 변환하기', '13.1 지리 공간 데이터와 GeoJSON', '13.2 GeoJSON 경계 파일 찾기', '13.3 GeoJson.io를 사용해 그리고 편집하기', '13.4 맵셰이퍼를 사용해 편집하고 병합하기', '13.5 압축된 KMZ를 KML로 변환하기', '13.6 맵 워퍼로 지오레퍼런스하기', '13.7 미국 통계청 지오코더를 사용해 대량으로 지오코딩하기', '13.8 포인트 데이터를 폴리곤 데이터로 피벗하기', '13.9 마치며', '[PART IV 진실하고 의미 있는 스토리 전달하기]', 'CHAPTER 14 거짓을 발견하고 편향 줄이기', '14.1 차트로 거짓말하는 방법', '14.2 지도로 거짓말하는 방법', '14.3 데이터 편향 인지하고 줄이기', '14.4 공간 편향 인지하고 줄이기', '14.5 마치며', 'CHAPTER 15 데이터 스토리 말하고 보여주기', '15.1 스토리보드에 내러티브 작성하기', '15.2 의미에 주의를 기울이세요', '15.3 출처와 불확실성 인정하기', '15.4 데이터 스토리 형식 결정하기', '15.5 마치며', 'APPENDIX 자주 발생하는 문제 해결법', 'A.1 도구 또는 플랫폼 문제', 'A.2 다른 브라우저 사용해보기', 'A.3 개발 도구로 진단하기', 'A.4 맥 또는 크롬북 문제', 'A.5 불량 데이터 체크하기', 'A.6 흔히 발생하는 iframe 에러', 'A.7 깃허브에서 코드 수정하기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B9063949643', 'title': 'IT CookBook, TCP/IP 소켓 프로그래밍(2판)', 'price': '32,000', 'content': ['Chapter 01 네트워크와 소켓 프로그래밍', '01 TCP/IP 프로토콜 개요', '02 소켓의 개념', '03 소켓의 특징과 구조', '04 소켓 프로그램 맛보기', '실습 1-1 윈도우 소켓 프로그램 작성과 테스트', '실습 1-2 리눅스 소켓 프로그램 작성과 테스트', '요약', '연습문제', 'Chapter 02 소켓 시작하기', '01 오류 처리', '02 소켓 초기화와 종료', '03 소켓 생성과 닫기', '실습 2-1 윈속 초기화와 종료하기', '실습 2-2 소켓 생성과 닫기', '요약', '연습문제', 'Chapter 03 소켓 주소 구조체 다루기', '01 소켓 주소 구조체', '02 바이트 정렬 함수', '03 IP 주소 변환 함수', '04 DNS와 이름 변환 함수', '실습 3-1 바이트 정렬 함수 연습', '실습 3-2 IP 주소 변환 함수 연습', '실습 3-3 이름 변환 함수 연습', '요약', '연습문제', 'Chapter 04 TCP 서버-클라이언트', '01 TCP 서버-클라이언트 구조', '02 TCP 서버-클라이언트 분석', '03 TCP 서버-클라이언트(IPv6)', '실습 4-1 TCP 서버-클라이언트 작성', '실습 4-2 TCP 서버-클라이언트 테스트', '실습 4-3 TCP 서버-클라이언트(IPv6) 작성과 테스트', '요약', '연습문제', 'Chapter 05 데이터 전송하기', '01 응용 프로그램 프로토콜과 데이터 전송', '02 다양한 데이터 전송 방식', '실습 5-1 고정 길이 데이터 전송 연습', '실습 5-2 가변 길이 데이터 전송 연습', '실습 5-3 고정 길이 + 가변 길이 데이터 전송 연습', '실습 5-4 데이터 전송 후 종료 연습', '요약', '연습문제', 'Chapter 06 멀티스레드: 윈도우', '01 스레드 기초', '02 스레드 API', '03 멀티스레드 TCP 서버', '04 스레드 동기화', '실습 6-1 스레드 생성과 종료, 인수 전달 연습', '실습 6-2 스레드 우선순위 변경 연습', '실습 6-3 스레드 실행 제어와 종료 기다리기 연습', '실습 6-4 멀티스레드 TCP 서버 작성과 테스트', '실습 6-5 임계 영역 연습', '실습 6-6 이벤트 연습', '요약', '연습문제', 'Chapter 07 멀티스레드: 리눅스', '01 스레드 API', '02 멀티스레드 TCP 서버', '03 스레드 동기화', '실습 7-1 스레드 생성과 종료, 인수 전달 연습', '실습 7-2 스레드 우선순위 변경 연습', '실습 7-3 스레드 종료 기다리기 연습', '실습 7-4 멀티스레드 TCP 서버 작성과 테스트', '실습 7-5 뮤텍스 연습', '실습 7-6 조건 변수 연습', '요약', '연습문제', 'Chapter 08 UDP 서버-클라이언트', '01 UDP 서버-클라이언트 구조', '02 UDP 서버-클라이언트 분석', '03 UDP 서버-클라이언트(IPv6)', '04 브로드캐스팅', '실습 8-1 UDP 서버-클라이언트 작성과 테스트', '실습 8-2 UDP 서버-클라이언트(IPv6) 작성과 테스트', '실습 8-3 UDP 브로드캐스팅 예제 작성과 테스트', '요약', '연습문제', 'Chapter 09 소켓 옵션', '01 소켓 옵션의 종류와 관련 함수', '02 SOL_SOCKET 레벨 옵션', '03 IPPROTO_IP, IPPROTO_IPV6 레벨 옵션', '04 IPPROTO_TCP 레벨 옵션', '실습 9-1 SO_REUSEADDR 옵션 테스트', '실습 9-2 멀티캐스팅(IPv4) 예제 작성과 테스트', '실습 9-3 멀티캐스팅(IPv6) 예제 작성과 테스트', '요약', '연습문제', 'Chapter 10 GUI 소켓 응용 프로그램: 윈도우', '01 GUI 응용 프로그램', '02 GUI 소켓 응용 프로그램', '03 대화상자 기반 응용 프로그램', '04 대화상자 기반 소켓 응용 프로그램', '실습 10-1 GUI 응용 프로그램 작성과 테스트', '실습 10-2 GUI 소켓 응용 프로그램 작성과 테스트', '실습 10-3 대화상자 기반 응용 프로그램 작성과 테스트', '실습 10-4 대화상자 기반 소켓 응용 프로그램 작성과 테스트', '요약', '연습문제', 'Chapter 11 소켓 입출력 모델: 윈도우', '01 소켓 입출력 모델 개요', '02 Select 모델', '03 WSAAsyncSelect 모델', '04 Completion Port 모델', '05 소켓 입출력 모델 비교', '실습 11-1 넌블로킹 소켓 연습', '실습 11-2 Select 모델 TCP 서버 작성과 테스트', '실습 11-3 WSAAsyncSelect 모델 TCP 서버 작성과 테스트', '실습 11-4 Completion Port 모델 TCP 서버 작성과 테스트', '요약', '연습문제', 'Chapter 12 소켓 입출력 모델: 리눅스', '01 소켓 입출력 모델 개요', '02 Select 모델', '03 Poll 모델', '04 EPoll 모델', '05 소켓 입출력 모델 비교', '실습 12-1 넌블로킹 소켓 연습', '실습 12-2 Select 모델 TCP 서버 작성과 테스트', '실습 12-3 Poll 모델 TCP 서버 작성과 테스트', '실습 12-4 EPoll 모델 TCP 서버 작성과 테스트', '요약', '연습문제', 'Chapter 13 직렬 통신과 블루투스 통신: 윈도우', '01 직렬 통신', '실습 13-1 직렬 통신 프로그램 작성과 테스트', '02 블루투스 통신', '실습 13-2 블루투스 장치 검색 프로그램 작성과 테스트', '실습 13-3 블루투스 통신 프로그램 작성과 테스트', '요약', '연습문제', 'Chapter 14 IPv4/IPv6 + TCP/UDP 지원 데이터 전송 프로그램', '01 프로젝트 개요', '02 응용 프로그램 작성', '실습 14-1 IPv4/IPv6 + TCP/UDP 지원 서버 작성', '실습 14-2 IPv4/IPv6 + TCP/UDP 지원 클라이언트 작성', '03 서버 코드 분석: 윈도우', '04 서버 코드 변환: 리눅스', '05 클라이언트 코드 분석', '06 추가 구현 사항']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B7400451696', 'title': 'IT CookBook, 쉽게 배우는 데이터 통신과 컴퓨터 네트워크(3판)', 'price': '30,000', 'content': ['Chapter 01 네트워크 기초', '01 용어의 정의', '02 구조적 모델', '03 주소의 표현', '요약', '연습문제', '현장의 목소리 01', 'Chapter 02 네트워크 개념', '01 프로토콜의 이해', '02 OSI 7계층 모델', '03 인터넷 모델', '요약', '연습문제', 'Chapter 03 네트워크 기술', '01 라우팅 기능', '02 네트워크의 분류', '03 인터네트워킹', '04 서비스 품질', '요약', '연습문제', 'Chapter 04 데이터 전송', '01 전송 방식', '02 오류 제어', '03 프레임 구조', '04 오류 검출 기법', '요약', '연습문제', '현장의 목소리 02', 'Chapter 05 MAC 계층', '01 IEEE 802 시리즈', '02 CSMA/CD', '03 토큰 버스', '04 토큰 링', '요약', '연습문제', 'Chapter 06 데이터 링크 계층', '01 프로토콜의 기초', '02 슬라이딩 윈도우 프로토콜', '03 HDLC 프로토콜', '요약', '연습문제', 'Chapter 07 IP 프로토콜', '01 네트워크 계층의 기능', '02 라우팅 프로토콜', '03 IP 프로토', '요약', '연습문제', '현장의 목소리 03', 'Chapter 08 네트워크 계층', '01 IPv6 프로토콜', '02 이동 IP 프로토콜', '03 제어용 프로토콜', '요약', '연습문제', 'Chapter 09 TCP 프로토콜', '01 전송 계층의 기능', '02 TCP의 헤더 구조', '03 TCP의 동작 원리', '요약', '연습문제', 'Chapter 10 전송 계층', '01 UDP 프로토콜', '02 RTP 프로토콜', '03 OSI TP 프로토콜', '요약', '연습문제', '현장의 목소리 04', 'Chapter 11 상위 계층', '01 상위 계층의 이해', '02 세션 계층', '03 표현 계층', '04 응용 계층', '요약', '연습문제', 'Chapter 12 네트워크 프로그래밍', '01 소켓의 주소 체계', '02 소켓 시스템 콜', '03 클라이언트ㆍ서버 프로그래밍', '요약', '연습문제', '현장의 목소리 05', 'Chapter 13 웹', '01 웹의 구조', '02 HTML의 기초', '03 HTTP 프로토콜', '04 CGI', '요약', '연습문제', 'Chapter 14 DNS', '01 주소의 변환', '02 네임 스페이스', '03 네임 서버와 해석기', '04 DNS 프로토콜', '요약', '연습문제', 'Chapter 15 전자 메일', '01 사용자 환경', '02 시스템 구조', '03 SMTP 프로토콜', '04 POP 서비스', '요약', '연습문제', '현장의 목소리 06', 'Chapter 16 파일 전송', '01 FTP 응용 프로그램', '02 FTP 프로토콜', '03 TFTP 프로토콜', '요약', '연습문제', 'Chapter 17 암호화와 네트워크 보안', '01 암호화의 이해', '02 암호화 시스템', '03 보안 프로토콜', '요약', '연습문제', '참고문헌', '찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B6129400746', 'title': 'IT CookBook, 우분투 리눅스(3판)', 'price': '34,000', 'content': ['PART 01 리눅스의 기본', 'Chapter 01 리눅스 설치와 기본 사용법', '00 개요', '01 리눅스 기초', '02 리눅스 실습 환경 구축', '03 리눅스 윈도 기본 사용법', '04 리눅스 명령 사용법', '연습문제', 'Chapter 02 디렉터리와 파일 사용법', '00 개요', '01 리눅스의 파일과 디렉터리', '02 디렉터리 관련 명령', '03 파일 관련 명령', '연습문제', 'Chapter 03 문서 편집', '00 개요', '01 리눅스의 문서 편집기', '02 vi 사용법', '03 vi 환경 설정', '연습문제', 'Chapter 04 셸 사용법', '00 개요', '01 셸의 기능과 종류', '02 셸 기본 사용법', '03 입출력 방향 변경', '04 배시셸 환경 설정', '05 앨리어스와 히스토리', '06 프롬프트 설정', '07 환경 설정 파일', '연습문제', 'Chapter 05 파일 접근 권한 관리', '00 개요', '01 파일 속성', '02 파일 접근 권한', '03 기호를 이용한 파일 접근 권한 변경', '04 숫자를 이용한 파일 접근 권한 변경', '05 기본 접근 권한 설정', '06 특수 접근 권한 설정', '연습문제', 'Chapter 06 프로세스 관리', '00 개요', '01 프로세스의 개념', '02 프로세스 관리 명령', '03 포그라운드ㆍ백그라운드 프로세스와 작업 제어', '04 작업 예약', '연습문제', 'PART 02 리눅스 시스템 관리', 'Chapter 07 파일 시스템과 디스크 관리', '00 개요', '01 리눅스 파일 시스템 종류', '02 리눅스 파일 시스템 구조', '03 파일 시스템 마운트', '04 디스크 추가 설치', '05 디스크 관리', '연습문제', 'Chapter 08 리눅스의 부팅과 종료', '00 개요', '01 리눅스 시스템의 부팅', '02 systemd 서비스', '03 리눅스 시스템의 종료', '04 데몬 프로세스', '05 부트 로더', '연습문제', 'Chapter 09 소프트웨어 관리', '00 개요', '01 우분투 패키지의 개요', '02 우분투 패키지 설치', '03 스냅 패키지 설치', '04 파일 아카이브와 압축', '05 소프트웨어 컴파일', '연습문제', 'Chapter 10 사용자 관리', '00 개요', '01 사용자 계정 관련 파일', '02 사용자 계정 관리 명령', '03 그룹 관리 명령', '04 사용자 정보 관리 명령', '05 디스크 사용량(쿼터) 설정', '연습문제', 'PART 03 리눅스 네트워크 서비스 관리', 'Chapter 11 네트워크 설정', '00 개요', '01 네트워크 기초', '02 네트워크 설정', '03 호스트 이름 설정', '04 네트워크 상태 확인', '연습문제', 'Chapter 12 원격 접속과 FTP', '00 개요', '01 텔넷과 SSH', '02 파일 송수신', '03 메일 송수신', '연습문제', 'Chapter 13 DB 서버와 웹 서버', '00 개요', '01 데이터베이스', '02 MariaDB 설치와 사용', '03 웹 서버 설치와 사용', '연습문제', 'Chapter 14 NFS와 삼바', '00 개요', '01 NFS 설치와 운영', '02 삼바 설치와 활용', '연습문제', 'PART 04 리눅스 보안 및 프로젝트', 'Chapter 15 리눅스 보안의 기초', '00 개요', '01 정보 보안의 기초', '02 시스템 로그', '03 방화벽 관리', '04 보안 관리 도구', '연습문제', 'Chapter 16 프로젝트', '01 프로젝트의 개요와 환경 구성', '02 프로젝트 시나리오', '연습문제', '찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B7738896383', 'title': '거시경제학(3판)', 'price': '36,000', 'content': ['제1편 거시경제학의 기초', '제1장 거시경제학의 주요 관심사', '제2장 거시경제의 측정 Ⅰ: 국민소득', '제3장 거시경제의 측정 Ⅱ: 인플레이션과 실업', '제4장 국민소득의 생산과 분배', '부록: 생산함수와 관계된 주요 거시경제변수', '제5장 지출 측면의 국민소득', '부록: 개방경제의 순환 과정', '제1편 요약', '제1편 연습문제', '제2편 국민소득 결정이론: 단순모형', '제6장 고전학파모형', '제7장 단순 케인즈모형', '제8장 실업: 고전학파 대 케인즈', '부록: 우리나라의 실업률과 경제성장률 추이 86', '제2편 요약', '제2편 연습문제', '제3편 화폐와 거시경제', '제9장 화폐와 금융시장', '제10장 화폐와 물가', '제11장 이자율: 고전학파 대 케인즈', '부록: 예상인플레이션과 물가 126', '제3편 요약', '제3편 연습문제', '제4편 거시경제의 수요 측면', '제12장 IS-LM 곡선의 도출', '제13장 IS-LM 모형과 재정·통화정책', '부록: 코로나 경제 위기에 대한 IS-LM 분석', '제14장 물가, 예상인플레이션과 IS-LM 모형', '부록: 수식으로 표현한 IS-LM 모형', '제4편 요약', '제4편 연습문제', '제5편 총수요·총공급모형', '제15장 단기와 장기', '제16장 총공급곡선의 도출 Ⅰ: 착오와 불완전정보', '제17장 총공급곡선의 도출Ⅱ: 임금과 가격의 경직성', '부록: 불완전경쟁과 총공급곡선', '제18장 기대형성과 총공급곡선', '제19장 총수요·총공급 충격과 경기변동', '제20장 필립스곡선', '부록: 우리나라의 필립스곡선과 오쿤의 법칙 248', '제5편 요약', '제5편 연습문제', '제6편 경제성장', '제21장 경제성장의 요인과 성장회계', '부록: 우리나라의 성장회계', '제22장 자본축적과 솔로우모형', '부록: 고령화와 경제성장률', '제23장 기술진보와 솔로우모형', '제24장 내생적 성장이론', '제6편 요약', '제6편 연습문제', '제7편 거시경제학의 미시경제적 기초', '제25장 소비이론 Ⅰ: 기본모형', '제26장 소비이론 Ⅱ: 다기간 선택', '제27장 소비이론 Ⅲ: 재정정책과 소비', '부록: 우리나라 소비 변동의 특성', '제28장 투자이론 Ⅰ: 기본모형', '부록: 자본의 한계효율과 투자의 한계효율', '제29장 투자이론 Ⅱ: 투자의 불안정성', '부록: 우리나라 설비투자 변동의 특성', '제30장 화폐의 공급', '제31장 화폐의 수요', '부록: 우리나라 화폐수요함수의 특성', '제7편 요약', '제7편 연습문제', '제8편 개방거시경제', '제32장 국제수지와 환율', '부록: 마샬-러너 조건의 도출', '제33장 구매력평가와 이자율평가', '부록: 국가위험도와 이자율평가', '제34장 개방거시경제모형: 수요 측면', '제35장 환율과 물가의 조정, 외환위기, 환율제도의 선택', '부록: 관리변동환율과 불태화 외환시장 개입', '제8편 요약', '제8편 연습문제', '제9편 경기변동과 안정화정책에 대한 논쟁', '제36장 새고전학파의 도전', '제37장 RBC 이론', '제38장 새케인즈학파의 주요 이론', '제39장 이자율 준칙과 IS-MP 모형', '제40장 안정화정책: 종합', '부록: 정부부채 비율의 계산', '제9편 요약', '제9편 연습문제', '부록 연습문제(선택형, 서술형) 해답 및 해설', '찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B4354575770', 'title': '생각하는 힘이 붙는 첫 숨은그림찾기', 'price': '6,300', 'content': []}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B1959656080', 'title': '실용적 접근 방식의 경영학원론(10판)', 'price': '39,000', 'content': ['PART 01 도입', 'CHAPTER 01 경영자', 'SECTION 01 경영의 의미', 'SECTION 02 경영의 네 가지 주요 기능', 'SECTION 03 경영의 수준과 분야', 'SECTION 04 경영자의 역할', 'SECTION 05 경영자에게 필요한 스킬', 'SECTION 06 경영자가 해결해야 할 일곱 가지 과제', 'SECTION 07 커리어 준비', 'SECTION 08 커리어 준비 실천', 'CHAPTER 02 경영 이론', 'SECTION 01 현대 경영 이론의 탄생 배경', 'SECTION 02 고전 이론', 'SECTION 03 행동주의 관점', 'SECTION 04 계량적 관점', 'SECTION 05 시스템 관점', 'SECTION 06 상황론적 관점', 'SECTION 07 최신 접근법', 'SECTION 08 커리어 준비 실천', 'PART 02 경영 환경', 'CHAPTER 03 경영 환경과 윤리적 책임', 'SECTION 01 비즈니스의 목적', 'SECTION 02 조직 내부의 이해관계자', 'SECTION 03 조직 외부의 이해관계자', 'SECTION 04 경영자에게 요구되는 윤리적 책임', 'SECTION 05 경영자에게 요구되는 사회적 책임', 'SECTION 06 기업 지배 구조', 'SECTION 07 커리어 준비 실천', 'CHAPTER 04 국제 경영', 'SECTION 01 세계화', 'SECTION 02 국제 경영과 글로벌 경영자', 'SECTION 03 기업의 해외 시장 진출 방식', 'SECTION 04 지역 경제의 협력과 경쟁', 'SECTION 05 문화적 차이 이해의 중요성', 'SECTION 06 커리어 준비 실천', 'PART 03 계획', 'CHAPTER 05 경영 계획', 'SECTION 01 계획과 전략', 'SECTION 02 계획의 기초', 'SECTION 03 목표와 계획', 'SECTION 04 목표의 일관성', 'SECTION 05 계획·통제 주기', 'SECTION 06 커리어 준비 실천', 'CHAPTER 06 전략 경영', 'SECTION 01 전략적 포지셔닝과 전략의 수준', 'SECTION 02 전략 경영 프로세스', 'SECTION 03 현상황 진단', 'SECTION 04 기업 수준 전략', 'SECTION 05 사업 수준 전략', 'SECTION 06 기능 수준 전략', 'SECTION 07 커리어 준비 실천', 'CHAPTER 07 개인과 집단 의사 결정', 'SECTION 01 합리적인 의사 결정과 비합리적인', 'SECTION 02 윤리적인 의사 결정', 'SECTION 03 증거 기반 의사 결정과 자료 분석', 'SECTION 04 인공 지능을 활용한 의사 결정', 'SECTION 05 의사 결정의 네 가지 스타일', 'SECTION 06 의사 결정의 열 가지 편향', 'SECTION 07 집단 의사 결정', 'SECTION 08 커리어 준비 실천', 'PART 04 조직', 'CHAPTER 08 조직 문화와 조직 구조', 'SECTION 01 전략에 맞추는 조직 문화, 조직 구조, HR 제도', 'SECTION 02 조직 문화', 'SECTION 03 조직 문화의 변화 과정', 'SECTION 04 조직 구조', 'SECTION 05 조직 구조의 유형', 'SECTION 06 커리어 준비 실천', 'CHAPTER 09 인적 자원 관리', 'SECTION 01 전략적 인적 자원 관리', 'SECTION 02 모집과 채용', 'SECTION 03 보상과 복리 후생', 'SECTION 04 학습과 개발', 'SECTION 05 성과 관리', 'SECTION 06 승진, 전출, 징계, 해고', 'SECTION 07 노사 관계', 'SECTION 08 커리어 준비 실천', 'CHAPTER 10 조직 변화와 혁신', 'SECTION 01 조직 변화', 'SECTION 02 조직 변화의 이론', 'SECTION 03 조직 개발', 'SECTION 04 조직 혁신', 'SECTION 05 조직 변화의 장애 요인', 'SECTION 06 커리어 준비 실천', 'PART 05 리드', 'CHAPTER 11 개인 차이와 행동', 'SECTION 01 성격과 개인 행동', 'SECTION 02 가치, 태도, 행동', 'SECTION 03 지각과 개인 행동', 'SECTION 04 직무 태도와 행동', 'SECTION 05 인력의 다양성', 'SECTION 06 스트레스와 개인 행동 이해', 'SECTION 07 커리어 준비 실천', 'CHAPTER 12 직원 동기 부여', 'SECTION 01 동기 부여', 'SECTION 02 동기 부여의 내용 이론', 'SECTION 03 동기 부여의 과정 이론', 'SECTION 04 동기 부여를 위한 직무 설계', 'SECTION 05 동기 부여를 위한 강화 이론', 'SECTION 06 동기 부여를 위한 보상', 'SECTION 07 커리어 준비 실천', 'CHAPTER 13 집단과 팀', 'SECTION 01 집단과 팀', 'SECTION 02 집단과 팀의 개발 과정', 'SECTION 03 효과적인 팀 구축', 'SECTION 04 갈등 관리', 'SECTION 05 커리어 준비 실천', 'CHAPTER 14 권력, 영향, 그리고 리더십', 'SECTION 01 권력과 영향', 'SECTION 02 리더십의 특성 이론', 'SECTION 03 리더십의 행동 이론', 'SECTION 04 리더십의 상황 이론', 'SECTION 05 거래적 리더십과 변혁적 리더십', 'SECTION 06 리더십의 최근 이론', 'SECTION 07 커리어 준비 실천', 'CHAPTER 15 의사소통', 'SECTION 01 의사소통의 의미와 과정', 'SECTION 02 의사소통의 경로', 'SECTION 03 의사소통의 장애물', 'SECTION 04 소셜 미디어 관리', 'SECTION 05 의사소통의 효과성', 'SECTION 06 커리어 준비 실천', 'PART 06 통제', 'CHAPTER 16 통제와 품질 경영', 'SECTION 01 통제', 'SECTION 02 통제 과정과 유형', 'SECTION 03 통제 방법', 'SECTION 04 전사적 품질 관리', 'SECTION 05 현대의 통제 방법', 'SECTION 06 커리어 준비 실천', 'SECTION 07 맺는 말: 미래의 성공과 행복을 위한 제언', 'Index', '부록', '- 학습 모듈 1', '- 학습 모듈 2', '※ 학습 모듈은 ‘https://hanbit.co.kr/src/4599’에서 내려받을 수 있습니다.']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B5171715268', 'title': '인피니티', 'price': '17,820', 'content': ['서문 | 과학이 허구를 넘어설 때', '들어가는 말 | 무한에 대하여', '우주의 무한 | 우주는 지금 몇 시일까', '양자의 무한 | 환영으로 이루어진 세계', '에필로그 | 진공의 숨결', '용어설명', '참고문헌']}
